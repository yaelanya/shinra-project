# %%
import pandas as pd
import json

import shinra_util as util

# %%
def read_json(filename):
    with open(filename, 'r', encoding='utf-8') as f:
        return json.load(f)
    return None

# %%
ENE_compound_list = util.read_jasonl("../data/ENE_compound_name.txt")
ENE_compound_dict = dict([[int(i['pageid']), i['title']] for i in ENE_compound_list])

# %%
furigana_dict = read_json("../output/furigana.json") 
other_name_dict = read_json("../output/other_name.json")
use_dict = read_json("../output/use.json")
type_dict = read_json("../output/type.json")
characteristic_dict = read_json("../output/characteristic.json")
material_dict = read_json("../output/material.json")
production_dict = read_json("../output/production.json")
CAS_dict = read_json("../output/cas_number.json")
chemical_formula_dict = read_json("../output/chemical_formula.json")
density_dict = read_json("../output/density.json")
melting_point_dict = read_json("../output/melting_point.json")
boiling_point_dict = read_json("../output/boiling_point.json")
indicative_formula_dict = read_json("../output/indicative_formula.json")

# %%
def is_null(_list: list):
     return len(_list) == 1 and len(_list[0]) == 0

def get_attribute(_dict: dict, _id: int):
    if _dict.get(str(_id)) and not is_null(_dict[str(_id)]):
        return _dict[str(_id)]
    elif _dict.get(int(_id)) and not is_null(_dict[int(_id)]):
        return _dict[int(_id)]
    else:
        return []
    
def get_attributes(_id: int):
    attributes = {}
    attributes['ふりがな'] = get_attribute(furigana_dict, _id)
    attributes['別称'] = get_attribute(other_name_dict, _id)
    attributes['用途'] = get_attribute(use_dict, _id)
    attributes['種類'] = get_attribute(type_dict, _id)
    attributes['商標名'] = []
    attributes['特性'] = get_attribute(characteristic_dict, _id)
    attributes['原材料'] = get_attribute(material_dict, _id)
    attributes['製造方法'] = get_attribute(production_dict, _id)
    attributes['生成化合物'] = []
    attributes['CAS番号'] = get_attribute(CAS_dict, _id)
    attributes['化学式'] = get_attribute(chemical_formula_dict, _id)
    attributes['密度'] = get_attribute(density_dict, _id)
    attributes['融点'] = get_attribute(melting_point_dict, _id)
    attributes['沸点'] = get_attribute(boiling_point_dict, _id)
    attributes['示性式'] = get_attribute(indicative_formula_dict, _id)
    
    return attributes

# %%
entry_list = []
for _id, title in ENE_compound_dict.items():
    entry = {}
    entry['ENE'] = "化合物名"
    entry['Name'] = title
    entry['WikipediaID'] = int(_id)
    entry['Attributes'] = get_attributes(int(_id))
    entry_list.append(entry)

# %%
output_dict = {'entry': entry_list}

# %%
with open("../output/result2.json", 'w') as f:
    json.dump(output_dict, f, ensure_ascii=False)

# %%
len(output_dict['entry'])
# Out:
# 5820

# %%
output_dict
# Out:
# {'entry': [{'ENE': '化合物名',
#    'Name': 'プルプリン',
#    'WikipediaID': 529580,
#    'Attributes': {'ふりがな': [],
#     '別称': [],
#     '用途': ['染料'],
#     '種類': ['染料'],
#     '商標名': [],
#     '特性': ['黄色', 'アルカリ性', '粉末', '茶色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['81-54-9'],
#     '化学式': ['C14H8O5'],
#     '密度': [],
#     '融点': ['253–256 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アクロレイン',
#    'WikipediaID': 95104,
#    'Attributes': {'ふりがな': [],
#     '別称': ['2-プロペナール', 'アクリルアルデヒド', 'acrolein', 'プロペンアルデヒド'],
#     '用途': ['殺菌剤', 'アルコール変性剤'],
#     '種類': ['アルデヒド'],
#     '商標名': [],
#     '特性': ['無色', '黄色', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['107-02-8'],
#     '化学式': ['C3H4O'],
#     '密度': ['0.8389'],
#     '融点': ['326 K', '-125 °F', '127 °F', '186 K', '−87 ℃', '−87 °C'],
#     '沸点': ['127 °F', '53 ℃', '326 K', '53 °C'],
#     '示性式': ['CH2=CHCHO']}},
#   {'ENE': '化合物名',
#    'Name': 'カリウムヘキサメチルジシラジド',
#    'WikipediaID': 3475525,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Potassium bis(trimethylsilyl)amide',
#      'Potassium hexamethyldisilazide'],
#     '用途': ['試薬', 'アミノ酸のアルキル化不斉合成'],
#     '種類': ['アミン', 'アミド', '有機化合物'],
#     '商標名': [],
#     '特性': ['結晶', '白色'],
#     '原材料': ['水素化カリウム', 'テトラヒドロフラン溶媒中', 'ビストリメチルシリルアミン'],
#     '製造方法': ['テトラヒドロフラン溶媒中で、水素化カリウムとビス(トリメチルシリル)アミンを反応させることで作られる。'],
#     '生成化合物': [],
#     'CAS番号': ['40949-94-8'],
#     '化学式': ['C6H18KNSi2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'イドース',
#    'WikipediaID': 964689,
#    'Attributes': {'ふりがな': [],
#     '別称': ['6-(hydroxymethyl)oxane-', 'idose', 'Ido', '2,3,4,5-tetrol'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['2152-76-3'],
#     '化学式': ['C6H12O6'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'セロトニン',
#    'WikipediaID': 78193,
#    'Attributes': {'ふりがな': [],
#     '別称': ['5-Hydroxytryptamine',
#      'Enteramine',
#      'Thrombocytin',
#      'serotonin',
#      '5-Hydroxytryptamine or',
#      'Thrombotonin',
#      '3-(β-Aminoethyl)-5-hydroxyindole',
#      '3-(2-Aminoethyl)indol-5-ol',
#      '5-HT'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['50-67-9'],
#     '化学式': ['C10H12N2O'],
#     '密度': [],
#     '融点': ['334 °F', '441 K', '167.7 °C', '121–122 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ベタニン',
#    'WikipediaID': 3102517,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Betanin',
#      '2,3-dihydro-6-',
#      'D-glucopyranosyloxy)-',
#      'hydroxy-1H-indol',
#      '2,3-dihydro-(S-(R*,R*))-2,6-pyridinedicarboxylic acid',
#      '-1-yl)ethenyl)-',
#      '4-(2-(2-carboxy-5-(beta-'],
#     '用途': ['冷凍食品',
#      'スープやトマト製品',
#      '食品',
#      '肉やソーセージの着色',
#      'フォンダン等の菓子',
#      '粉末飲料等の着色',
#      '乾燥食品や賞味期限'],
#     '種類': ['色素', '抗酸化物質'],
#     '商標名': [],
#     '特性': ['赤色', '感受性', '黄茶色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7659-95-2'],
#     '化学式': ['C24H26N2O13'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'セメンタイト',
#    'WikipediaID': 104244,
#    'Attributes': {'ふりがな': [],
#     '別称': ['cementite'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '超酸化ナトリウム',
#    'WikipediaID': 2071809,
#    'Attributes': {'ふりがな': 'ちょうさんかナトリウム',
#     '別称': ['sodium(I) superoxide', 'sodium superoxide'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['結晶', '黄色', '粉末'],
#     '原材料': ['過酸化ナトリウム', '300気圧', '高温高圧下', '酸素'],
#     '製造方法': ['過酸化ナトリウムと酸素を500℃以上・300気圧以上の高温高圧下で反応することにより得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['12034-12-7'],
#     '化学式': ['NaO2'],
#     '密度': [],
#     '融点': ['551.7℃'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アルドース',
#    'WikipediaID': 445091,
#    'Attributes': {'ふりがな': [],
#     '別称': ['aldose'],
#     '用途': ['化学の用語', 'アルデヒド基', '単糖類', '化学式'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '1,3,5-トリオキサン',
#    'WikipediaID': 789866,
#    'Attributes': {'ふりがな': [],
#     '別称': ['5-trioxane', '1', '3'],
#     '用途': ['水溶液', '固形燃料'],
#     '種類': ['有機化合物', '酸', 'アセタール'],
#     '商標名': [],
#     '特性': ['白色', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['110-88-3'],
#     '化学式': ['C3H6O3'],
#     '密度': ['65', '1.17 g/cm3'],
#     '融点': ['64 °C'],
#     '沸点': ['114.5 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フェニレフリン',
#    'WikipediaID': 1230775,
#    'Attributes': {'ふりがな': [],
#     '別称': ['(R)-3-(1-hydroxy-2-(methylamino)ethyl)phenol', 'phenylephrine'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['61-76-7', '59-42-7'],
#     '化学式': ['C9H13NO2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'エスゾピクロン',
#    'WikipediaID': 2477369,
#    'Attributes': {'ふりがな': [],
#     '別称': ['(S)-6-(5-Chloro-2-pyridinyl)- 7-oxo- 6,7-dihydro- 5H-pyrrolo[3,4-b]pyrazin-5-yl- 4-methyl- 1-piperazinecarboxylate',
#      'Eszopiclone'],
#     '用途': ['食品衛生審議会', '薬事'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['長時間苦味', '苦味'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['138729-47-2'],
#     '化学式': ['C17H17ClN6O3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ノルメラトニン',
#    'WikipediaID': 3004595,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Normelatonin',
#      'N-acetyl-5-HT',
#      'N-[2-(5-hydroxy-1H-indol-3-yl)ethyl]acetamide',
#      'N-acetyl-5-hydroxytryptamine'],
#     '用途': ['起立性低血圧の原因', 'モノアミン酸化酵素阻害薬'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['セロトニン作動性'],
#     '原材料': ['化合物',
#      'セロトニン',
#      'メラトニン',
#      'ノルメラトニン',
#      'アセチルセロトニン',
#      'メラトニン合成',
#      'セロトニン',
#      'メラトニン',
#      'ノルメラトニン',
#      '脳',
#      '前駆体',
#      '中枢神経系',
#      '低血圧効果',
#      '血圧',
#      'メラトニン',
#      'ノルメラトニン',
#      'クロルギリン'],
#     '製造方法': ['ノルメラトニン(Normelatonin)またはN-アセチルセロトニン(N-Acetylserotonin)は、セロトニンからのメラトニンの合成の中間体として、天然に生成する化合物である。',
#      'さらにノルメラトニンは、セロトニンもメラトニンも分布しない脳の特定の画分に分布し、これは単にメラトニン合成の前駆体としての役割を果たすだけではなく、中枢神経系における独自の機能を持つことが示唆されている。',
#      'ノルメラトニンはネズミの血圧を低下させ、松果体切除は、ノルメラトニンやメラトニンの合成の場である）によって、クロルギリンの低血圧効果はなくなる。'],
#     '生成化合物': [],
#     'CAS番号': ['1210-83-9'],
#     '化学式': ['C12H14N2O2'],
#     '密度': ['1.268 g/mL'],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '塩化ウラン(VI)',
#    'WikipediaID': 3352098,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Uranium hexachloride',
#      '塩化ウラン(IV',
#      'Uranium(VI) chloride',
#      '六塩化ウラン'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['結晶', '液体', '緑色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['13763-23-0'],
#     '化学式': ['UCl6'],
#     '密度': ['3.600 g/cm3'],
#     '融点': ['348 K', '450 K', '351 °F', '177 °C', '167 °F'],
#     '沸点': ['167 °F', '348 K', '75 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'インデン',
#    'WikipediaID': 1861077,
#    'Attributes': {'ふりがな': [],
#     '別称': ['indene', 'ベンゾシクロペンタジエン'],
#     '用途': [],
#     '種類': ['炭化水素'],
#     '商標名': [],
#     '特性': ['無色', '二環性', '熱可塑性', '可燃性', '液体', '黄色'],
#     '原材料': ['金属ナトリウム'],
#     '製造方法': ['その留分を金属ナトリウムと加熱して sodio-indene として沈殿させる。'],
#     '生成化合物': [],
#     'CAS番号': ['95-13-6'],
#     '化学式': ['C9H8'],
#     '密度': ['0.9968'],
#     '融点': ['-1.8 ℃'],
#     '沸点': ['181.6 ℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ペデリン',
#    'WikipediaID': 2816025,
#    'Attributes': {'ふりがな': [],
#     '別称': ['pederin',
#      '(2S)-N-[(S)-[(2S,4R,6R)-6-[(2S)-2,3-dimethoxypropyl]-4-hydroxy-5,5-dimethyl-2-tetrahydropyranyl]-methoxymethyl]-2-hydroxy-2-[(2R,5R,6R)-2-methoxy-5,6-dimethyl-4-methylene-2-tetrahydropyranyl]acetamide',
#      'Pederine'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['ペデリン', '卵'],
#     '製造方法': ['幼虫および雄は母親から（すなわち卵を通して）獲得するか、摂取したペデリンのみを貯蔵する。'],
#     '生成化合物': [],
#     'CAS番号': ['27973-72-4'],
#     '化学式': ['C25H45NO9'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'メタプロスカリン',
#    'WikipediaID': 3074055,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Metaproscaline', '2-(3,4-dimethoxy-5-propoxyphenyl)ethanamine'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['毒性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['90132-33-5'],
#     '化学式': ['C13H21NO3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フルクトース-6-リン酸',
#    'WikipediaID': 1266443,
#    'Attributes': {'ふりがな': 'フルクトース-6-リンさん',
#     '別称': ['[(2R,3R,4S)-3,4,5-トリヒドロキシ-5- (ヒドロキシメチル)オキソラン-2-イル]メトキシホスホン酸',
#      'Fructose 6-phosphate',
#      'F6P'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['加水分解', '物質', 'エステル', 'フルクトース-2', 'ビスリン酸'],
#     '製造方法': ['1918年、カール・ノイベルグは当時ハーデン-ヤングエステルと呼ばれたフルクトース-2,6-ビスリン酸の緩い酸加水分解によってある物質が生成することを見出した。'],
#     '生成化合物': [],
#     'CAS番号': ['643-13-0'],
#     '化学式': ['C6H13O9P'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アクリル酸メチル',
#    'WikipediaID': 1682529,
#    'Attributes': {'ふりがな': 'アクリルさんメチル',
#     '別称': ['methyl acrylate', 'プロペン酸メチル'],
#     '用途': ['不純物', '酢酸メチルやプロピオン酸メチル', 'アクリル樹脂の原料', '他の樹脂の共重合原料'],
#     '種類': ['有機化合物', 'エステル'],
#     '商標名': [],
#     '特性': ['無色', '液体', '安全性'],
#     '原材料': ['メタノール', 'エチレンシアノヒドリン', '硫酸'],
#     '製造方法': ['HC ≡ CH + CO + CH 3 OH ⟶ H 2 C = CH − COOCH 3 また、エチレンシアノヒドリンにメタノールと硫酸を反応させることでも合成することができる。'],
#     '生成化合物': [],
#     'CAS番号': ['96-33-3'],
#     '化学式': ['C4H6O2'],
#     '密度': ['0.956 g/cm³'],
#     '融点': ['−75 ºC'],
#     '沸点': ['80 ºC'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリペプチド',
#    'WikipediaID': 3581465,
#    'Attributes': {'ふりがな': [],
#     '別称': ['tripeptide'],
#     '用途': ['美容製品', '皮膚の再生'],
#     '種類': ['アミノ酸', '抗生物質', 'ペプチド', '抗酸化物質', 'ホルモン'],
#     '商標名': [],
#     '特性': ['免疫活性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '低次フラーレン',
#    'WikipediaID': 3342016,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Lower fullerenes'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['信頼性'],
#     '原材料': ['フラーレン合成', '塩素化フラーレンC50Cl10', '四塩化炭素'],
#     '製造方法': ['厦門大学のXieらは、グラファイトに四塩化炭素を混ぜて放電によるフラーレン合成を行うことにより、極少量ながら安定した塩素化フラーレンC50Cl10を得ることに成功している。'],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ボルネオール',
#    'WikipediaID': 227982,
#    'Attributes': {'ふりがな': [],
#     '別称': ['borneol'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['無色', '揮発性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['464-43-7', '507-70-0', '464-45-9'],
#     '化学式': ['C10H18O'],
#     '密度': ['1.011 g/cm3'],
#     '融点': ['208 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '安息香酸カリウム',
#    'WikipediaID': 1574379,
#    'Attributes': {'ふりがな': 'あんそくこうさんカリウム',
#     '別称': ['Potassium benzoate'],
#     '用途': ['防腐剤', '食品', 'いくつかの真正細菌の成長'],
#     '種類': ['安息香酸', '酢酸'],
#     '商標名': [],
#     '特性': ['白色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['582-25-2'],
#     '化学式': ['C7H5KO2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ナラシン',
#    'WikipediaID': 2338922,
#    'Attributes': {'ふりがな': [],
#     '別称': ['narasin',
#      '(2R)-2-[(2R,3S,5S,6R)-6-[(1S,2S,3S,5R)-5- [(2S,5S,7R,9S,10S,12R,15R)-2-[(2R,5R,6S)-5-ethyl-5-hydroxy-6-methyl-2-tetrahydropyranyl]-15-hydroxy-2,10,12-trimethyl-1,6,8-trioxadispiro[4.1.57.35]pentadec-13-en-9-yl]-2-hydroxy-1,3-dimethyl-4-oxoheptyl]-3,5-dimethyl-2-tetrahydropyranyl]butanoic acid',
#      '(4S)-4-methyl-salinomycin 化学的データ'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['55134-13-9'],
#     '化学式': ['C43H72O11'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '亜硝酸',
#    'WikipediaID': 161438,
#    'Attributes': {'ふりがな': 'あしょうさん',
#     '別称': ['nitrous acid', 'ジオキソ硝酸', 'ジオキソ硝酸 '],
#     '用途': ['ソーセージなどの食品添加物', '遊離酸の状態', '亜硝酸エステル等の形', '鮮赤色'],
#     '種類': ['オキソ酸'],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['硫酸水溶液', '硝酸', '硫酸バリウム', '一酸化窒素', '亜硝酸バリウム', '遊離酸'],
#     '製造方法': ['遊離酸を得るには亜硝酸バリウムに当量の硫酸水溶液を加え、硫酸バリウムを沈降濾別したり、硝酸に一酸化窒素を作用させるとよい。'],
#     '生成化合物': [],
#     'CAS番号': ['7758-09-0',
#      '7632-00-0',
#      '13465-94-6',
#      '109-95-5',
#      '110-46-3',
#      '544-16-1',
#      '543-67-9',
#      '7783-99-5',
#      '542-56-3',
#      '540-80-7',
#      '541-42-4',
#      '13780-06-8'],
#     '化学式': ['HNO2'],
#     '密度': ['1'],
#     '融点': [],
#     '沸点': ['103℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '炭酸銀(I)',
#    'WikipediaID': 847067,
#    'Attributes': {'ふりがな': 'たんさんぎん いち',
#     '別称': ['炭酸銀', 'silver(I) carbonate'],
#     '用途': [],
#     '種類': ['無機化合物', '炭酸塩'],
#     '商標名': [],
#     '特性': ['粉末'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['534-16-7'],
#     '化学式': ['Ag2CO3'],
#     '密度': ['6.077 g/cm3'],
#     '融点': ['210 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '臭素酸銀(I)',
#    'WikipediaID': 1866524,
#    'Attributes': {'ふりがな': 'しゅうそさんぎん いち',
#     '別称': ['silver(I) bromate'],
#     '用途': ['銀系抗菌剤', 'ハロゲン化安息香酸類製造時の触媒'],
#     '種類': ['無機化合物', '触媒'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7783-89-3'],
#     '化学式': ['AgBrO3'],
#     '密度': ['5.206 g/cm3'],
#     '融点': ['582 K', '588 °F', '309 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ショウガオール',
#    'WikipediaID': 2217120,
#    'Attributes': {'ふりがな': [],
#     '別称': ['(6)-Shogaol',
#      'Shogaol',
#      '(E)-1-(4-Hydroxy-3- methoxyphenyl)dec-4-en-3-one'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['555-66-8'],
#     '化学式': ['C17H24O3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'クロロトリメチルシラン',
#    'WikipediaID': 2585955,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Trimethylsilyl chloride', 'TMCS', 'TMSCl'],
#     '用途': ['化学',
#      'ガラス器具',
#      '元のカルボニル基のアルファ位',
#      '保護基',
#      'トリメチルシリル基の供給源',
#      '塩素の無水供給源',
#      '官能基',
#      '二重結合の酸化',
#      '表面の親油性',
#      'トリメチルシリル基の不安定性',
#      'アルコール中',
#      '向山アルドール反応',
#      'トリメチルシリルハロゲンや擬ハロゲンの合成の出発物質',
#      '無水塩酸の製造',
#      '色々',
#      'ヒドロキシ基'],
#     '種類': ['有機ケイ素化合物'],
#     '商標名': [],
#     '特性': ['無色', '液体', '核性'],
#     '原材料': ['メチルリチウム等', '四塩化ケイ素', '塩素原子', '求核置換反応'],
#     '製造方法': ['四塩化ケイ素の3つの塩素原子をメチルリチウム等の求核性のメチル源で求核置換反応することで得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['75-77-4'],
#     '化学式': ['C3H9SiCl'],
#     '密度': ['0.856 g/cm3'],
#     '融点': ['-40 °C', '330.2 K', '233.2 K'],
#     '沸点': ['330.2 K', '57 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ホスホリボシル二リン酸',
#    'WikipediaID': 1318833,
#    'Attributes': {'ふりがな': 'ホスホリボシルにりんさん',
#     '別称': ['Phosphoribosyl diphosphate'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['リボースリン酸ジホスホキナーゼ', 'リン酸', 'リボース'],
#     '製造方法': ['リボース-5-リン酸からリボースリン酸ジホスホキナーゼによって作られる。'],
#     '生成化合物': [],
#     'CAS番号': ['7540-64-9'],
#     '化学式': ['C5H13O14P3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '酸化オスミウム(VIII)',
#    'WikipediaID': 74409,
#    'Attributes': {'ふりがな': 'さんかオスミウム はち',
#     '別称': ['VIII', 'osmium(VIII) oxide', 'osmium tetroxide'],
#     '用途': ['オスミウム試薬の使用量', '等モル量', '再酸化剤', '酸化', '電子顕微鏡', '触媒量'],
#     '種類': ['酸化物'],
#     '商標名': [],
#     '特性': ['黄色'],
#     '原材料': ['無色',
#      '黄色',
#      '固体',
#      'オスミウム',
#      'ジオール',
#      '酸化オスミウム(VIII)',
#      '酸化剤',
#      'アルケン',
#      'クロラミンT',
#      'アミノアルコール'],
#     '製造方法': ['無色から淡黄色の固体で、オスミウムを加熱すると容易に生じる。',
#      '有機合成分野において酸化オスミウム(VIII)は、アルケンを 1,2-ジオールへと変換する重要な酸化剤として用いられる。',
#      'また反応系にクロラミンTなどを共存させておくことにより、アミノアルコールを合成することもできる。'],
#     '生成化合物': [],
#     'CAS番号': ['20816-12-0'],
#     '化学式': ['OsO4'],
#     '密度': [],
#     '融点': ['42 °C', '40.25 °C'],
#     '沸点': ['129.7 °C', '130 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'イソプロピル-β-チオガラクトピラノシド',
#    'WikipediaID': 1223240,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Isopropyl β-D-1-thiogalactopyranoside'],
#     '用途': ['分子生物学', '組み換えタンパク質の発現', '試薬の一つ', '誘導物質', '1.5mMの濃度範囲'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['信頼性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['367-93-1'],
#     '化学式': ['C9H18O5S'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'Α-メチルトリプタミン',
#    'WikipediaID': 566361,
#    'Attributes': {'ふりがな': [],
#     '別称': ['IT-290',
#      '3-IT 化学的データ',
#      'IT-403',
#      'Indopan',
#      'U-14,164E',
#      '2-(1H-indol-3-yl)-1-methyl-ethylamine'],
#     '用途': ['効果と多幸感'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['299-26-3'],
#     '化学式': ['C11H14N2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '3,5-ジヒドロキシ安息香酸',
#    'WikipediaID': 3042885,
#    'Attributes': {'ふりがな': [],
#     '別称': ['5-Dihydroxybenzoic acid',
#      'alpha-Resorcylic acid',
#      '3,5-dihydroxybenzoic acid',
#      '3'],
#     '用途': [],
#     '種類': ['ジヒドロキシ安息香酸'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['99-10-5'],
#     '化学式': ['C7H6O4'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トラニラスト',
#    'WikipediaID': 3457795,
#    'Attributes': {'ふりがな': [],
#     '別称': ['2-{[(2E)-3-(3,4-dimethoxyphenyl)prop-2- enoyl]amino}benzoic acid',
#      'Tranilast'],
#     '用途': ['内服薬', 'ケロイドや肥厚性瘢痕の治療', 'アレルギー性疾患の治療'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['53902-12-8'],
#     '化学式': ['C18H17NO5'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'クロトン酸エチル',
#    'WikipediaID': 3135123,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Ethyl trans-2-butanoate', 'Ethyl crotonate'],
#     '用途': ['有機合成化学の原料', 'イチゴやパイナップルなどのフルーツ系香料'],
#     '種類': ['エステル'],
#     '商標名': [],
#     '特性': ['無色', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['10544-63-5', '623-70-1'],
#     '化学式': ['C6H10O2'],
#     '密度': [],
#     '融点': [],
#     '沸点': ['138 °C', '280 °F', '411 K'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フェンタニル',
#    'WikipediaID': 293373,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Fentanyl'],
#     '用途': ['副作用の呼吸抑制',
#      'フェンタニルの注射剤',
#      '疼痛緩和の目的',
#      '癌性疼痛の緩和',
#      '1996年のWHO方式がん疼痛治療法の3段階中の3段階目',
#      '合成オピオイド',
#      'オピオイド'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C22H28N2O'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ウリジン二リン酸ガラクトース',
#    'WikipediaID': 1383785,
#    'Attributes': {'ふりがな': 'ウリジンにリンさんガラクトース',
#     '別称': ['Uridine diphosphate galactose'],
#     '用途': [],
#     '種類': ['糖類'],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['グルコース',
#      'グルコース-1',
#      'リン酸',
#      'ガラクトース-1',
#      'ガラクトース',
#      'リン酸ウリジリルトランスフェラーゼ'],
#     '製造方法': ['ガラクトース-1-リン酸ウリジリルトランスフェラーゼにより、UDP-グルコースとガラクトース-1-リン酸からUDP-ガラクトースとグルコース-1-リン酸が作られる。'],
#     '生成化合物': [],
#     'CAS番号': ['2956-16-3'],
#     '化学式': ['C15H24N2O17P2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリプトファン',
#    'WikipediaID': 43585,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Tryptophan',
#      'Tryptophan or (2S)-2-amino-3-(1H-indol-3-yl)propanoic acid',
#      '2-Amino-3-(1H-indol-3-yl)propanoic acid'],
#     '用途': ['輸液用製剤',
#      '肝硬変の患者',
#      '通常の患者',
#      'トリプトファン等の肝性脳症リスク',
#      'アミノ酸輸液',
#      '物質の配合量',
#      '製剤'],
#     '種類': ['アミノ酸', 'ホルモン'],
#     '商標名': [],
#     '特性': ['糖原性', '恒常性', 'ケト原性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['73-22-3'],
#     '化学式': ['C11H12N2O2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '酪酸ヘプチル',
#    'WikipediaID': 2272668,
#    'Attributes': {'ふりがな': [],
#     '別称': ['ブタン酸ヘプチル'],
#     '用途': ['香料', 'お茶', 'グリーン香'],
#     '種類': ['酪酸エステル'],
#     '商標名': [],
#     '特性': ['無色', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['5870-93-9'],
#     '化学式': ['C11H22O2'],
#     '密度': [],
#     '融点': ['-58~-57℃'],
#     '沸点': ['225℃'],
#     '示性式': ['C3H7COOC7H15']}},
#   {'ENE': '化合物名',
#    'Name': '亜硫酸マグネシウム',
#    'WikipediaID': 2036370,
#    'Attributes': {'ふりがな': 'ありゅうさんマグネシウム',
#     '別称': ['Magnesium sulfite'],
#     '用途': ['亜硫酸ガスの脱硫'],
#     '種類': ['無機化合物', '亜硫酸塩'],
#     '商標名': [],
#     '特性': ['吸湿性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7757-88-2'],
#     '化学式': ['MgSO3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ポリビニルポリピロリドン',
#    'WikipediaID': 3116193,
#    'Attributes': {'ふりがな': [],
#     '別称': ['1-ethenylpyrrolidin-2-one',
#      'Polyvinylpolypyrrolidone',
#      'crospolividone',
#      'Polyvinyl polypyrrolidone',
#      'PVPP',
#      'crospovidone',
#      'E1202'],
#     '用途': ['E番号', 'ワイン醸造等', '錠剤', '木炭', '医薬品の錠剤の崩壊剤', '薬剤', '骨炭', '不純物の清澄剤'],
#     '種類': ['医薬品', 'ポリフェノール', 'タンニン'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['25249-54-1'],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'テトラフェニルメタン',
#    'WikipediaID': 1674779,
#    'Attributes': {'ふりがな': [],
#     '別称': ['tetraphenylmethane'],
#     '用途': [],
#     '種類': ['芳香族炭化水素', '水素'],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['トリチル誘導体3',
#      'フェニルヒドラジン2',
#      'トリフェニルブロモメタン',
#      'アゾ化合物4',
#      '酸化',
#      '亜硝酸',
#      '窒素分子',
#      'テトラフェニルメタン5',
#      '溶融熱分解'],
#     '製造方法': ['トリフェニルブロモメタン（臭化トリチル, 1）をフェニルヒドラジン (2) と反応させてトリチル誘導体 3 を得た。',
#      'それを亜硝酸で酸化してアゾ化合物 4 とし、溶融熱分解により窒素分子を遊離させてテトラフェニルメタン (5) を得た。'],
#     '生成化合物': [],
#     'CAS番号': ['630-76-2'],
#     '化学式': ['C25H20'],
#     '密度': [],
#     '融点': ['272 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '2-ピロリドン',
#    'WikipediaID': 2409378,
#    'Attributes': {'ふりがな': 'または2-ピロリジノン',
#     '別称': ['2-Pyrrolidinone', 'γ-ブチロラクタム', '2-Pyrrolidone'],
#     '用途': ['工業用溶媒', 'ベンゼンなど多くの溶媒', 'ポリビニルピロリドンなど高分子化合物の中間体'],
#     '種類': ['溶媒', '有機化合物', 'ピロリドン'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['616-45-5'],
#     '化学式': ['C4H7NO'],
#     '密度': ['1.116 g/cm³'],
#     '融点': ['280 °F', '25 °C', '264 °F', '77 °F', '518 K', '473 °F', '298 K'],
#     '沸点': ['280 °F', '518 K', '473 °F', '264 °F', '245 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'バラトール',
#    'WikipediaID': 966675,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Baratol'],
#     '用途': [],
#     '種類': ['爆薬'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '炭化カルシウム',
#    'WikipediaID': 912670,
#    'Attributes': {'ふりがな': 'たんかカルシウム',
#     '別称': ['アセチレノーゲン', 'カルシウムカーバイド', 'カルシウムアセチリド'],
#     '用途': ['アセチレンガスの簡便', '灰色'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['灰色', '白色', '結晶', '不快臭', '灰白色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['75-20-7'],
#     '化学式': ['CaC2'],
#     '密度': ['2.22 g/cm3'],
#     '融点': ['2160 ℃'],
#     '沸点': ['2300 ℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '3-ベンズヒドリルモルホリン',
#    'WikipediaID': 3020450,
#    'Attributes': {'ふりがな': [],
#     '別称': ['3-(diphenylmethyl)morpholine', '3-Benzhydrylmorpholine'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['93406-27-0'],
#     '化学式': ['C17H19NO'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'オイルシェールガス',
#    'WikipediaID': 2571064,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Oil shale gas'],
#     '用途': ['天然ガスの代替物', 'ガス灯の燃料', 'オイルシェール', '熱分解', 'シェール油抽出時の副産物', '燃料'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['シェール油抽出時', '熱分解', 'オイルシェールガス', '燃料', 'オイルシェール'],
#     '製造方法': ['オイルシェールガスはシェール油抽出時の副産物としても生成されるため、その生産方法次第ではオイルシェールを熱分解する燃料にも利用し得る。'],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ジクロロメタン',
#    'WikipediaID': 1835437,
#    'Attributes': {'ふりがな': [],
#     '別称': ['dichloromethane',
#      'メチレンクロリド',
#      'UN 1593',
#      '二塩化メタン',
#      'methylene dichloride',
#      '塩化メチレン',
#      'R-30',
#      'ソラエスチン',
#      'Freon 30',
#      'MDC',
#      'ソルメチン',
#      'Dichloromethane',
#      'アエロテンMM',
#      'DCM',
#      'ナルコチル',
#      'Di-clo'],
#     '用途': ['金属加工業',
#      '溶媒',
#      '溶媒や溶剤',
#      'オゾン層破壊問題',
#      '中心',
#      '金属機器の洗浄剤の代替物質',
#      '一部のフロン類',
#      'アシル化反応',
#      '有機化学',
#      '酸性条件',
#      'スワン酸化などの酸化反応',
#      '沸点',
#      '有機合成の溶媒'],
#     '種類': ['溶媒', '有機化合物'],
#     '商標名': [],
#     '特性': ['無色', '毒性', '液体', '発がん性'],
#     '原材料': ['メタン', 'クロロメタン', '慣用名', '塩素', '塩化メチル'],
#     '製造方法': ['工業的には、メタンあるいはクロロメタン（慣用名は塩化メチル）と塩素とを400-500℃で気相でラジカル反応させることで得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['75-09-2'],
#     '化学式': ['CH2Cl2'],
#     '密度': ['1.3266 g/cm³'],
#     '融点': ['175.7 K', '−96.7 ºC', '312.8 K'],
#     '沸点': ['312.8 K', '40 ºC'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '臭化リチウム',
#    'WikipediaID': 1819631,
#    'Attributes': {'ふりがな': 'しゅうかリチウム',
#     '別称': ['Lithium bromide'],
#     '用途': ['躁病や双極性障害の治療'],
#     '種類': ['臭化物'],
#     '商標名': [],
#     '特性': ['白色'],
#     '原材料': ['炭酸リチウム', '水溶液', '臭化水素酸', '水酸化リチウム'],
#     '製造方法': ['炭酸リチウムあるいは水酸化リチウムと臭化水素酸を反応させると水溶液が得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['7550-35-8'],
#     '化学式': ['LiBr'],
#     '密度': ['3.464 g/cm3'],
#     '融点': ['552℃'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'パロノセトロン',
#    'WikipediaID': 3080504,
#    'Attributes': {'ふりがな': [],
#     '別称': ['(3aS)-2-[(3S)-1-Azabicyclo[2.2.2]oct-3-yl]-2,3,3a,4,5,6-hexahydro-1H-benz[de]isoquinolin-1-one',
#      'palonosetron'],
#     '用途': ['悪心',
#      '頭痛',
#      '大規模臨床試験',
#      '治験時の副作用発現率',
#      '癌化学療法',
#      '発性の悪心',
#      '化学療法誘発性悪心嘔吐',
#      'シスプラチン等',
#      '遅延性の悪心',
#      '抗悪性腫瘍剤',
#      '急性期の悪心',
#      '3受容体拮抗薬の一つ'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['遅延性', '発性', '急性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['135729-61-2'],
#     '化学式': ['C19H24N2O'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アラキジルアルコール',
#    'WikipediaID': 2787290,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Icosyl hydrate',
#      'イコサン-1-オール',
#      'Icosylic alcohol',
#      'イコサアルコール',
#      'オコサノール',
#      'Arachidalcohol Arachidic alcohol',
#      '1-Icosanol',
#      'ノナデシルカルビノール',
#      '[ˌæræˈkɪdɪl ˌælkoʊˈhɒl]',
#      'イコシルアルコール',
#      'arachidyl alcohol',
#      'Hydroxyicosane',
#      '1-イコサノール n-イコサノール'],
#     '用途': ['化粧品の保', '状物質'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['結晶', '白色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['629-96-9'],
#     '化学式': ['C20H42O'],
#     '密度': [],
#     '融点': ['337 K', '702 °F', '64 °C', '645 K', '147 °F'],
#     '沸点': ['645 K', '372 °C', '702 °F'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フッ化銅(II)',
#    'WikipediaID': 1598196,
#    'Attributes': {'ふりがな': 'フッかどう に',
#     '別称': ['Copper fluoride', 'Cupric fluoride', 'Copper difluoride'],
#     '用途': [],
#     '種類': ['無機化合物'],
#     '商標名': [],
#     '特性': ['白色', '結晶', '変色', '吸湿性', '粉末'],
#     '原材料': ['気体フッ素'],
#     '製造方法': ['銅と気体フッ素の反応で得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['7789-19-7', '13454-88-1'],
#     '化学式': ['CuF2'],
#     '密度': ['4.23 g/cm3', '2.934 g/cm3'],
#     '融点': ['836 °C'],
#     '沸点': ['1676 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '三酸化テルル',
#    'WikipediaID': 486727,
#    'Attributes': {'ふりがな': [],
#     '別称': ['酸化テルル(VI)', 'tellurium trioxide'],
#     '用途': [],
#     '種類': ['無機化合物', '酸化物'],
#     '商標名': [],
#     '特性': ['結晶', '橙色'],
#     '原材料': ['三酸化テルル', '脱水', 'テルル酸', '塩素ガス', '塩酸中'],
#     '製造方法': ['三酸化テルルは通常、テルル酸 (telluric acid, Te(OH)6) を 300 ℃近辺に加熱し、脱水することで得られる。',
#      '濃塩酸中で加熱すると塩素ガスが生じる。'],
#     '生成化合物': [],
#     'CAS番号': ['13451-18-8'],
#     '化学式': ['TeO3'],
#     '密度': ['5.07 g/cm3'],
#     '融点': ['703 K', '806 °F', '430 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ヘキサオキソトリシクロブタベンゼン',
#    'WikipediaID': 2992259,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Hexaoxotricyclobutabenzene'],
#     '用途': [],
#     '種類': ['ケトン', '有機化合物'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['144191-88-8'],
#     '化学式': ['C12O6'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ベンザイン',
#    'WikipediaID': 502920,
#    'Attributes': {'ふりがな': [],
#     '別称': ['benzyne'],
#     '用途': [],
#     '種類': ['水素'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C6H4'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フェリクローム',
#    'WikipediaID': 3652819,
#    'Attributes': {'ふりがな': [],
#     '別称': ['N-[3-[4,16-ビス[3-[アセチル(オキシド)アミノ]プロピル]-2,5,8,11,14,17-ヘキサオキソ-3,6,9,12,15,18-ヘキサアザシクロオクタデ-1-シル]プロピル]-N-オキシドアセトアミド',
#      '鉄(3+',
#      'Ferrichrome'],
#     '用途': [],
#     '種類': ['ヒドロキサム酸'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['15630-64-5'],
#     '化学式': ['C27H42FeN9O12'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ボセンタン',
#    'WikipediaID': 2011096,
#    'Attributes': {'ふりがな': [],
#     '別称': ['4-tert-butyl-N-[6-(2-hydroxyethoxy)-5-(2-methoxyphenoxy)-2-(pyrimidin-2-yl)pyrimidin-4-yl]benzene-1-sulfonamide',
#      'トラクリア',
#      'BOZENTAN'],
#     '用途': ['潰瘍', 'おもに肺高血圧の治療', '肺動脈性肺高血圧', 'IVの患者', '治療薬'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['147536-97-8'],
#     '化学式': ['C27H29N5O6S'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アルブチン',
#    'WikipediaID': 788226,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Arbutoside',
#      'Hydroquinone β-D-glucopyranoside',
#      'arbutin',
#      '(2R,3S,4S,5R,6S)-2-Hydroxymethyl-6- (4-hydroxyphenoxy)oxane-3,4,5-triol'],
#     '用途': ['メラニンの合成', 'メラニン合成', '化粧品', '美白効果'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['497-76-7'],
#     '化学式': ['C12H16O7'],
#     '密度': [],
#     '融点': ['391 °F', '473 K', '199.5 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アリストロキア酸',
#    'WikipediaID': 1518622,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Aristolochic acid'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['313-67-7'],
#     '化学式': ['C17H11NO7'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '七酸化二塩素',
#    'WikipediaID': 500528,
#    'Attributes': {'ふりがな': 'しちさんかにえんそ',
#     '別称': ['七酸化塩素', '無水過塩素酸'],
#     '用途': [],
#     '種類': ['無機化合物', '酸化物', '酸無水物'],
#     '商標名': [],
#     '特性': ['無色', '液体'],
#     '原材料': ['脱水剤', '五酸化二リン', '過塩素酸'],
#     '製造方法': ['過塩素酸に脱水剤として五酸化二リンを作用させながら慎重に蒸留して得る。'],
#     '生成化合物': [],
#     'CAS番号': ['12015-53-1'],
#     '化学式': ['Cl2O7'],
#     '密度': [],
#     '融点': ['−91.5 ℃'],
#     '沸点': ['82 ℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ヘプテン',
#    'WikipediaID': 3020459,
#    'Attributes': {'ふりがな': [],
#     '別称': ['hept-1-ene', 'Heptene'],
#     '用途': ['潤滑油の添加物', '触媒', '界面活性剤'],
#     '種類': ['アルケン', '触媒', '界面活性剤'],
#     '商標名': [],
#     '特性': ['無色', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['592-76-7'],
#     '化学式': ['C7H14'],
#     '密度': ['0.697 g/mL'],
#     '融点': ['-119 °C', '367 K', '201 °F', '154 K', '-182 °F', '16 °F'],
#     '沸点': ['94 °C', '367 K', '16 °F', '201 °F'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ネブラセタム',
#    'WikipediaID': 2914253,
#    'Attributes': {'ふりがな': [],
#     '別称': ['(RS)-4-(aminomethyl)-1-benzylpyrrolidin-2-one', 'Nebracetam'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['97205-34-0'],
#     '化学式': ['C12H16N2O'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フッ化バナジウム(IV)',
#    'WikipediaID': 3096245,
#    'Attributes': {'ふりがな': [],
#     '別称': ['vanadium tetrafluoride', 'Vanadium tetrafluoride'],
#     '用途': [],
#     '種類': ['無機化合物'],
#     '商標名': [],
#     '特性': ['黄茶色', '常磁性', '吸湿性', '無臭', '粉末'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['10049-16-8'],
#     '化学式': ['VF4', 'F4V'],
#     '密度': ['23', '20', '2.975 g/cm3', '3.15 g/cm3'],
#     '融点': ['598 K', '325 °C', '617 °F', '760 mmHg'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'メタンジオール',
#    'WikipediaID': 1601814,
#    'Attributes': {'ふりがな': [],
#     '別称': ['methanediol', 'Methanediol'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['463-57-0'],
#     '化学式': ['CH4O2', 'H2C'],
#     '密度': ['3', '1.199 g cm−3'],
#     '融点': [],
#     '沸点': ['381 °F', '467 K', '194 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'チグリルCoA',
#    'WikipediaID': 2856653,
#    'Attributes': {'ふりがな': [],
#     '別称': ['S-[2-[3-[[(2R)-4-[[[(2R,3S,4R,5R)-5-(6-Aminopurin-9-yl)-4-hydroxy-3-phosphonooxyoxolan-2-yl]methoxy-hydroxyphosphoryl]oxy-hydroxyphosphoryl]oxy-2-hydroxy-3,3-dimethylbutanoyl]amino]propanoylamino]ethyl] (E)-2-methylbut-2-enethioate',
#      'tiglyl-CoA'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['6247-62-7'],
#     '化学式': ['C26H42N7O17P3S'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '硫酸アンモニウム鉄(II)',
#    'WikipediaID': 2341656,
#    'Attributes': {'ふりがな': 'りゅうさんアンモニウムてつに',
#     '別称': ['Ammonium iron(II) sulfate',
#      'モール塩',
#      '硫酸アンモニウム鉄(II',
#      '硫酸第一鉄アンモニウム',
#      '硫酸鉄(II)アンモニウム',
#      'ammonium iron(II) sulfate'],
#     '用途': ['酸化', '試薬', '滴定', '分析化学'],
#     '種類': ['無機化合物'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7783-85-9', '10045-89-3'],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'セミカルバジド',
#    'WikipediaID': 1759413,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Semicarbazide'],
#     '用途': ['薄層クロマトグラフィー', '発色試薬'],
#     '種類': ['尿素'],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['尿素ヒドラジンチオセミカルバジドカルボニル化合物'],
#     '製造方法': ['尿素 ヒドラジン チオセミカルバジド カルボニル化合物と反応させるとセミカルバゾン（英語版）が得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['57-56-7'],
#     '化学式': ['H2NNHC(=O)NH2'],
#     '密度': [],
#     '融点': ['96 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'フラボガロン酸',
#    'WikipediaID': 2577371,
#    'Attributes': {'ふりがな': [],
#     '別称': ['flavogallonic acid'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C21H14O12'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'マンノビオース',
#    'WikipediaID': 3101419,
#    'Attributes': {'ふりがな': [],
#     '別称': [],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '二酸化炭素',
#    'WikipediaID': 6958,
#    'Attributes': {'ふりがな': 'にさんかたんそ',
#     '別称': ['ドライアイス（固体', 'carbon dioxide', '炭酸ガス', 'Carbon dioxide'],
#     '用途': ['コーヒーのデカフェ',
#      '観賞用水槽の水草',
#      '植物の成長',
#      '消火剤などの発泡用ガス',
#      'ドライアイス洗浄',
#      '炭酸ガスレーザー',
#      'ドライアイス',
#      '冷却用ドライアイス',
#      'レーザー',
#      '二酸化炭素施肥',
#      '炭酸飲料や入浴剤',
#      '白煙',
#      '医療用レーザーメス',
#      'カフェインの抽出溶媒',
#      'イチゴの促成栽培'],
#     '種類': ['無機化合物', '酸化物', '有機化合物'],
#     '商標名': [],
#     '特性': ['無色', '気体', '液体', '緑色'],
#     '原材料': ['二酸化炭素', '炭化水素'],
#     '製造方法': ['東京工業大学の岩澤伸治教授らは、二酸化炭素を炭化水素と反応させる有機合成反応を開発した。'],
#     '生成化合物': [],
#     'CAS番号': ['124-38-9'],
#     '化学式': ['CO2'],
#     '密度': ['0.770 g/cm3', '0.001977 g/cm3', '1.562 g/cm3'],
#     '融点': ['-69.88°F',
#      '194.7 K',
#      '216.6 K',
#      '760 mmHg',
#      '−56.6 °C',
#      '-109.3°F'],
#     '沸点': ['-109.3°F', '194.7 K', '760 mmHg', '−78.5 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ボスチニブ',
#    'WikipediaID': 3081097,
#    'Attributes': {'ふりがな': [],
#     '別称': ['4-[(2,4-dichloro-5-methoxyphenyl)amino]-6-methoxy-7-[3-(4-methylpiperazin-1-yl)propoxy]quinoline-3-carbonitrile',
#      'Bosutinib'],
#     '用途': ['チロシンキナーゼ阻害作用',
#      '分子標的薬',
#      '慢性骨髄性白血病',
#      '慢性骨髄性白血病の治療',
#      '染色体陽性',
#      '抗がん剤'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['380843-75-4'],
#     '化学式': ['C26H29Cl2N5O3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'イソチアゾール',
#    'WikipediaID': 1246499,
#    'Attributes': {'ふりがな': [],
#     '別称': [],
#     '用途': [],
#     '種類': ['医薬品', 'チアゾール'],
#     '商標名': [],
#     '特性': ['液体', '生理活性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['288-16-4'],
#     '化学式': ['C3H3NS'],
#     '密度': ['1.078 g/cm3'],
#     '融点': [],
#     '沸点': ['114 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ステアリルアルコール',
#    'WikipediaID': 2694429,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Octadecan-1-ol',
#      'Octadecyl alcohol',
#      'Stearyl alcohol',
#      'stearyl alcohol'],
#     '用途': ['化粧品等', '潤滑油', '樹脂'],
#     '種類': ['脂肪族アルコール', '脂肪酸', '触媒', '有機化合物'],
#     '商標名': [],
#     '特性': ['低い毒性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['112-92-5'],
#     '化学式': ['C18H38O'],
#     '密度': ['0.812 g/cm³'],
#     '融点': ['365 °F', '59.4-59.8 °C'],
#     '沸点': ['365 °F', '210 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'デルフィニジン',
#    'WikipediaID': 1563264,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Delphinidin',
#      '2-(3,4,5-trihydroxyphenyl)chromenylium-3,5,7-triol'],
#     '用途': [],
#     '種類': ['色素', '抗酸化物質', 'アントシアニジン'],
#     '商標名': [],
#     '特性': ['塩基性', '依存性', '青色', '赤紫色', '赤色', '酸性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['528-53-0', '13270-61-6'],
#     '化学式': ['C15H11O7'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '1-アミノ-2-プロパノール',
#    'WikipediaID': 2439943,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Monoisopropanolamine',
#      '1-amino-2-propanol',
#      '1-Aminopropan-2-ol',
#      'Threamine',
#      'Isopropanolamine'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['酸化プロピレン', '水性アンモニア'],
#     '製造方法': ['水性アンモニアと酸化プロピレンから合成できる。'],
#     '生成化合物': [],
#     'CAS番号': ['78-96-6'],
#     '化学式': ['C3H9NO'],
#     '密度': ['0.973 g/mL'],
#     '融点': ['-2 °C', '433 K', '320 °F', '271 K', '28 °F'],
#     '沸点': ['160 °C', '320 °F', '433 K'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリアコンタノール',
#    'WikipediaID': 2799198,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Triacontan-1-ol',
#      '1-Triacontanol n-Triacontanol',
#      '1-triacontanol',
#      'Myricyl alcohol',
#      'Melissyl alcohol'],
#     '用途': [],
#     '種類': ['脂肪族アルコール'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['593-50-0'],
#     '化学式': ['C30H62O'],
#     '密度': [],
#     '融点': ['87 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '発煙硝酸',
#    'WikipediaID': 210852,
#    'Attributes': {'ふりがな': 'はつえんしょうさん',
#     '別称': ['WFNA', 'White Fuming Nitric Acid'],
#     '用途': ['化学', 'ロケット燃料', '抑制剤', '酸の一種', 'ニトロ化反応の試薬', '電子密度'],
#     '種類': ['酸化剤', '酸'],
#     '商標名': [],
#     '特性': ['赤色', '赤褐色', '気体', '白色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ロテノン',
#    'WikipediaID': 1411318,
#    'Attributes': {'ふりがな': [],
#     '別称': ['rotenone',
#      '(2R,6aS,12aS)-2-イソプロペニル-8,9-ジメトキシ-1,2,6,6a,12,12a-ヘキサヒドロクロメノ[3,4-b]フロ[2,3-h]クロメン-6-オン',
#      'ツバトキシン',
#      'パラデリル'],
#     '用途': ['乳液', '殺虫剤', '農薬'],
#     '種類': ['殺虫剤', '農薬'],
#     '商標名': [],
#     '特性': ['無色', '無臭', '赤色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['83-79-4'],
#     '化学式': ['C23H22O6'],
#     '密度': ['20', '1.27'],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ルビセン',
#    'WikipediaID': 3323535,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Rubicene'],
#     '用途': [],
#     '種類': ['炭化水素'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['179-61-5'],
#     '化学式': ['C26H14'],
#     '密度': [],
#     '融点': ['305 ℃'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'クロム酸',
#    'WikipediaID': 884244,
#    'Attributes': {'ふりがな': 'クロムさん',
#     '別称': ['chromic acid', 'ジヒドロキシジオキソクロム'],
#     '用途': [],
#     '種類': ['オキソ酸', 'クロム化合物', '塩'],
#     '商標名': [],
#     '特性': ['赤色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7738-94-5'],
#     '化学式': ['H2CrO4'],
#     '密度': ['1.201 g/cm3'],
#     '融点': ['197°C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アシベンゾラル',
#    'WikipediaID': 2860338,
#    'Attributes': {'ふりがな': [],
#     '別称': ['acibenzolar'],
#     '用途': ['殺菌剤'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['殺菌活性', '抵抗性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['126448-41-7'],
#     '化学式': ['C7H4N2OS2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アンセリン',
#    'WikipediaID': 2821511,
#    'Attributes': {'ふりがな': [],
#     '別称': ['anserine',
#      '(2S)-2-[(3-Amino-1-oxopropyl)amino]-3-(3-methyl-4-imidazolyl)propanoic acid',
#      'beta-Alanyl-N(pi)-methyl-L-histidine'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['584-85-0'],
#     '化学式': ['C10H16N4O3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリス(ジベンジリデンアセトン)ジパラジウム(0)',
#    'WikipediaID': 1408504,
#    'Attributes': {'ふりがな': [],
#     '別称': [],
#     '用途': ['遷移金属触媒',
#      '有機合成化学',
#      '配位子',
#      '触媒の前駆体',
#      '根岸カップリングやキャロル転位',
#      '不斉アリル位アルキル化反応の触媒'],
#     '種類': ['触媒', 'パラジウム化合物'],
#     '商標名': [],
#     '特性': ['紫色'],
#     '原材料': ['トリスジベンジリデンアセトンジパラジウム0',
#      '触媒',
#      'パラジウム',
#      'ジベンジリデンアセトン',
#      '錯体',
#      '遷移金属触媒',
#      '有機合成化学',
#      '前駆体'],
#     '製造方法': ['トリス(ジベンジリデンアセトン)ジパラジウム(0)（Tris(dibenzylideneacetone)dipalladium(0)、Pd2(dba)3）は、パラジウムとジベンジリデンアセトン (DBA) からなる錯体で、有機合成化学において遷移金属触媒、あるいは触媒の前駆体として用いられる。'],
#     '生成化合物': [],
#     'CAS番号': ['51364-51-3'],
#     '化学式': ['C51H42O3Pd2'],
#     '密度': [],
#     '融点': ['152 -155 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ゴシポール',
#    'WikipediaID': 3212347,
#    'Attributes': {'ふりがな': [],
#     '別称': ['1,1′,6,6′,7,7′‐Hexahydroxy‐3,3′‐dimethyl‐5,5′‐diisopropyl‐2,2′‐binaphthalene‐8,8′‐dicarbaldehyde',
#      'Gossypol'],
#     '用途': [],
#     '種類': ['テルペノイド', '有機化合物', '水素'],
#     '商標名': [],
#     '特性': ['黄色'],
#     '原材料': ['生合成', '有機化合物', '酸素', '水素', '炭素', 'ゴシポール', 'テルペノイド'],
#     '製造方法': ['ゴシポール（Gossypol）は、炭素と酸素と水素のみからなる有機化合物の1種で、ワタが生合成するテルペノイドとして知られる。'],
#     '生成化合物': [],
#     'CAS番号': ['303-45-7'],
#     '化学式': ['C30H30O8'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アセチレンジカルボン酸',
#    'WikipediaID': 2734409,
#    'Attributes': {'ふりがな': [],
#     '別称': ['2-Butynedioic acid',
#      'But-2-ynedioic acid',
#      'Acetylenedicarboxylic acid'],
#     '用途': ['試薬', 'アセチレンジカルボン酸ジメチルの合成'],
#     '種類': ['ジカルボン酸', '酸'],
#     '商標名': [],
#     '特性': ['結晶性'],
#     '原材料': ['水素化アセチレンジカルボン酸アニオンHC4O4',
#      'イオン化',
#      'メタノール',
#      '臭化カリウム',
#      'ジブロモコハク酸',
#      'エタノール中',
#      '水酸化カリウム',
#      'アセチレンジカルボン酸カリウム'],
#     '製造方法': ['部分的なイオン化では、一価の水素化アセチレンジカルボン酸アニオンHC4O4-が得られる。',
#      'メタノールまたはエタノール中で、α,β-ジブロモコハク酸を水酸化カリウムで処理することによって、臭化カリウムとアセチレンジカルボン酸カリウムが生成する。'],
#     '生成化合物': [],
#     'CAS番号': ['142-45-0'],
#     '化学式': ['C4H2O4'],
#     '密度': [],
#     '融点': ['175–176 °C'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'スリソベンゾン',
#    'WikipediaID': 3263674,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Sulisobenzone'],
#     '用途': ['360nmまでの紫外線', '紫外線吸収剤'],
#     '種類': ['有機化合物'],
#     '商標名': [],
#     '特性': ['黄色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C14H12O6S'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'パキポドール',
#    'WikipediaID': 2524204,
#    'Attributes': {'ふりがな': [],
#     '別称': ['5-hydroxy-2-(4-hydroxy-3-methoxyphenyl)-3,7-dimethoxychromen-4-one',
#      "Quercetin 3,7,3'-trimethyl ether",
#      "4',5-Dihydroxy-3,3',7-trimethoxyflavone",
#      'pachypodol'],
#     '用途': [],
#     '種類': ['有機化合物'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['33708-72-4'],
#     '化学式': ['C18H16O7'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '塩化ウラン(IV)',
#    'WikipediaID': 3350823,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Uranium(IV) chloride',
#      'Uranium tetrachloride',
#      'Uranous chloride',
#      'Tetrachlorouranium'],
#     '用途': ['電磁的同位体分離', '電磁的同位体分離法', 'ウラン濃縮'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': ['酸化ウラン(VI)',
#      '塩化ウランIV(IV)',
#      '酸化ウランIV(IV)',
#      '電磁的同位体分離',
#      '塩化ウランIV(IV)',
#      'ウラン濃縮',
#      '四塩化炭素'],
#     '製造方法': ['塩化ウラン(IV)は一般的には酸化ウラン(VI)とヘキサクロロプロペンを反応させて生成する。',
#      '塩化ウラン(IV)は商業的には純粋な酸化ウラン(IV)と四塩化炭素を370 ℃で反応させることで生産されており、電磁的同位体分離（electromagnetic isotope separation、EMIS)によるウラン濃縮に利用されている。'],
#     '生成化合物': [],
#     'CAS番号': ['10026-10-5'],
#     '化学式': ['UCl4'],
#     '密度': ['4.87 g/cm3'],
#     '融点': ['590 °C', '1064 K', '863 K', '1094 °F', '1456 °F'],
#     '沸点': ['1456 °F', '1064 K', '791 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ペンタノナコンタン',
#    'WikipediaID': 2956933,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Pentanonacontane'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7667-97-2'],
#     '化学式': ['C95H192'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリニトロトルエン',
#    'WikipediaID': 31833,
#    'Attributes': {'ふりがな': [],
#     '別称': ['略称TNT', '2,4,6-トリニトロトルエン', 'trinitrotoluene'],
#     '用途': [],
#     '種類': ['水素'],
#     '商標名': [],
#     '特性': ['黄色', '安全性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['118-96-7'],
#     '化学式': ['C7H5N3O6'],
#     '密度': ['1.65 g/cm3'],
#     '融点': ['80.1 ℃'],
#     '沸点': ['240 ℃'],
#     '示性式': ['C6H2CH3(NO2)3']}},
#   {'ENE': '化合物名',
#    'Name': '非対称ジメチルヒドラジン',
#    'WikipediaID': 9951,
#    'Attributes': {'ふりがな': 'または1,1-ジメチルヒドラジン',
#     '別称': ['UDMH',
#      'Unsymmetrical dimethylhydrazine',
#      '1-ジメチルヒドラジン',
#      '1,1-Dimethylhydrazine'],
#     '用途': [],
#     '種類': ['有機化合物', 'ヒドラジン'],
#     '商標名': [],
#     '特性': ['変色', 'アンモニア臭', '吸湿性', '黄色', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['57-14-7'],
#     '化学式': ['C2H8N2'],
#     '密度': ['790 mg mL−1', '20', '790', '1'],
#     '融点': ['216 K', '-57 °C', '-71 °F', '337.1 K', '147 °F'],
#     '沸点': ['147 °F', '337.1 K', '64 °C'],
#     '示性式': ['CH']}},
#   {'ENE': '化合物名',
#    'Name': '硝酸ストロンチウム',
#    'WikipediaID': 1871446,
#    'Attributes': {'ふりがな': 'しょうさんストロンチウム',
#     '別称': ['Strontium nitrate'],
#     '用途': ['花火の火薬', '深紅色の炎色反応'],
#     '種類': ['硝酸塩'],
#     '商標名': [],
#     '特性': ['無色', '結晶', '依存性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['10042-76-9'],
#     '化学式': ['Sr(NO3)2'],
#     '密度': ['2.986 g/cm3'],
#     '融点': ['570 ℃'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '硫化亜鉛',
#    'WikipediaID': 708170,
#    'Attributes': {'ふりがな': 'りゅうかあえん',
#     '別称': ['Zinc sulfide'],
#     '用途': ['アルファ線やX線や電子線',
#      'N型半導体とP型半導体の両方',
#      '電子線',
#      'ブラウン管の材料',
#      '族半導体',
#      'X線の増感剤',
#      '部品',
#      'ドーピング'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['共有結合性', '白色', '結晶', '黄色', '粉末'],
#     '原材料': ['亜鉛', '水溶液', '硫化水素', '硫黄', '亜鉛イオン'],
#     '製造方法': ['硫黄と亜鉛の直接化合、または亜鉛イオンを含む水溶液に硫化水素を吹き込むことで生成する。'],
#     '生成化合物': [],
#     'CAS番号': ['1314-98-3'],
#     '化学式': [],
#     '密度': [],
#     '融点': ['1991 K', '1718 ℃'],
#     '沸点': ['1180 ℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'カルシウムシアナミド',
#    'WikipediaID': 636103,
#    'Attributes': {'ふりがな': [],
#     '別称': ['calcium cyanamide', '白色石灰窒素'],
#     '用途': ['石灰窒素の有効成分', '肥料'],
#     '種類': ['触媒', '肥料'],
#     '商標名': [],
#     '特性': ['灰色', '白色', '黒色', '有害性', '無臭'],
#     '原材料': ['カルシウムカーバイド', '窒素分子', '2気圧'],
# ...
#      '生成物は分留によって精製され、残渣として硫酸水素ナトリウムが得られる。',
#      'その他にも塩化ナトリウムと硝酸銀を混合すると NaCl + AgNO 3 ⟶ NaNO 3 + AgCl の反応によって塩化銀が沈澱するので硝酸ナトリウムを得ることができる。'],
#     '生成化合物': [],
#     'CAS番号': ['7631-99-4'],
#     '化学式': ['NaNO3'],
#     '密度': [],
#     '融点': ['308 ℃'],
#     '沸点': ['380 ℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ヨウ化ジルコニウム(IV)',
#    'WikipediaID': 1658575,
#    'Attributes': {'ふりがな': [],
#     '別称': ['四ヨウ化ジルコニウム', 'Zirconium(IV) iodide'],
#     '用途': [],
#     '種類': ['無機化合物', 'ヨウ化物'],
#     '商標名': [],
#     '特性': ['黄橙色', '結晶', '揮発性', '橙色', '粉末'],
#     '原材料': ['ヨウ素', '粉末', 'ジルコニウム'],
#     '製造方法': ['粉末のジルコニウムとヨウ素を直接反応させることによって合成できる。'],
#     '生成化合物': [],
#     'CAS番号': ['13986-26-0'],
#     '化学式': ['ZrI4'],
#     '密度': ['4.580 g/cm3'],
#     '融点': ['499 °C'],
#     '沸点': ['431 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリオクタコンタン',
#    'WikipediaID': 2956903,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Trioctacontane'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7667-90-5'],
#     '化学式': ['C83H168'],
#     '密度': [],
#     '融点': [],
#     '沸点': ['760mmHg', '687.192 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アベルメクチン',
#    'WikipediaID': 3292929,
#    'Attributes': {'ふりがな': [],
#     '別称': [],
#     '用途': ['寄生虫感染症治療法の開発',
#      '家畜の線形動物や節足動物感染症',
#      'マラリア感染症治療',
#      '2015年のノーベル生理学・医学賞'],
#     '種類': ['マクロライド'],
#     '商標名': [],
#     '特性': ['駆虫活性', '殺虫活性'],
#     '原材料': ['駆虫薬', '基', 'イベルメクチン', 'アベルメクチン'],
#     '製造方法': ['アベルメクチンを基に合成された駆虫薬には、イベルメクチン、セラメクチン（英語版）、ドラメクチン（英語版）がある。'],
#     '生成化合物': [],
#     'CAS番号': ['65195-55-3', '65195-56-4'],
#     '化学式': ['B1b）', 'B1a）', 'C47H70O14（avermectin', 'C48H72O14（avermectin'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'サリチルアルデヒド',
#    'WikipediaID': 693683,
#    'Attributes': {'ふりがな': [],
#     '別称': ['salicylaldehyde'],
#     '用途': ['有機金属化学',
#      'エチレンジアミンと縮',
#      'バター',
#      '香料',
#      '香料などの用途',
#      '配位子',
#      'シナモンやフルーツ系のフレーバー'],
#     '種類': ['フェノール', '有機化合物', 'ベンズアルデヒド', 'イミン'],
#     '商標名': [],
#     '特性': ['無色', '急性経口毒性', '急性経皮毒性', '液体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['90-02-8'],
#     '化学式': ['C7H6O2'],
#     '密度': ['20', '1.167 g/cm3'],
#     '融点': ['−7 °C'],
#     '沸点': ['196–197 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリアジン',
#    'WikipediaID': 517929,
#    'Attributes': {'ふりがな': [],
#     '別称': ['triazine', 'C3H3N3'],
#     '用途': ['除草剤', '殺菌剤', '農薬'],
#     '種類': ['複素環式化合物', 'トリアジン'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': ['80°C'],
#     '沸点': ['114°C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ホスフィンオキシド',
#    'WikipediaID': 2338453,
#    'Attributes': {'ふりがな': [],
#     '別称': ['phosphine oxide'],
#     '用途': [],
#     '種類': ['有機リン化合物'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': [],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ジピベフリン',
#    'WikipediaID': 3008182,
#    'Attributes': {'ふりがな': [],
#     '別称': ['[2-(2,2-dimethylpropanoyloxy)-4- (1-hydroxy-2-methylamino-ethyl)- phenyl] 2,2-dimethylpropanoate',
#      'Dipivefrine'],
#     '用途': ['アドレナリンのプロドラッグ'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['52365-63-6'],
#     '化学式': ['C19H29NO5'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'メトホルミン',
#    'WikipediaID': 2118025,
#    'Attributes': {'ふりがな': [],
#     '別称': ['N,N-dimethylimidodicarbonimidic diamide',
#      'Metformin',
#      '1,1-dimethylbiguanide 化学的データ'],
#     '用途': ['ビグアナイド系薬剤',
#      '経口糖尿病治療薬の一つ',
#      '脂肪肝や血中の脂質レベルの改善',
#      '基質分子のリン酸化亢進',
#      '中性脂肪やコレステロールの合成'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['657-24-9'],
#     '化学式': ['C4H11N5'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '一酸化硫黄',
#    'WikipediaID': 482822,
#    'Attributes': {'ふりがな': 'いっさんかいおう',
#     '別称': ['Sulfur monoxide[要出典]', 'sulfur monoxide'],
#     '用途': [],
#     '種類': ['ジエン'],
#     '商標名': [],
#     '特性': ['無色', '気体', '興味'],
#     '原材料': ['ジエン', '一酸化硫黄'],
#     '製造方法': ['一酸化硫黄の生成はジエンなどで捕捉することによって確認される。'],
#     '生成化合物': [],
#     'CAS番号': ['13827-32-2'],
#     '化学式': ['SO'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'サキナビル',
#    'WikipediaID': 3285249,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Saquinavir',
#      '(2S)-N-[(2S,3R)-4-[(3S)-3-(tert-butylcarbamoyl)-decahydroisoquinolin-2-yl]-3-hydroxy-1-phenylbutan-2-yl]-2-(quinolin-2-ylformamido)butanediamide'],
#     '用途': ['経口抗ウイルス薬の一つ',
#      'プロテアーゼ阻害薬の一つ',
#      'ソフトカプセル製剤でも充分',
#      '患者',
#      '臨床的',
#      'リトナビル'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['127779-20-8'],
#     '化学式': ['C38H50N6O5'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ビニルアセチレン',
#    'WikipediaID': 3001295,
#    'Attributes': {'ふりがな': [],
#     '別称': ['butenyne', 'Vinylacetylene', 'but-1-en-3-yne', '3-butene-1-yne'],
#     '用途': ['有機化学工業'],
#     '種類': ['アルケン', '炭化水素', 'アルキン', '有機化合物'],
#     '商標名': [],
#     '特性': ['無色', '気体'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['689-97-4'],
#     '化学式': ['C4H4'],
#     '密度': [],
#     '融点': [],
#     '沸点': ['0-6 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アエロバクチン',
#    'WikipediaID': 3063139,
#    'Attributes': {'ふりがな': [],
#     '別称': ['(8S,16S)-3,12,21-Trihydroxy-2,10,14,22-tetraoxo-3,9,15,21-tetraazatricosane-8,12,16-tricarboxylic acid',
#      'Aerobactin'],
#     '用途': [],
#     '種類': ['触媒'],
#     '商標名': [],
#     '特性': ['細菌性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['26198-65-2'],
#     '化学式': ['C22H36N4O13'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'カルバモイルリン酸',
#    'WikipediaID': 1298016,
#    'Attributes': {'ふりがな': 'カルバモイルリンさん',
#     '別称': ['Carbamoyl phosphate'],
#     '用途': [],
#     '種類': ['ピリミジン', '触媒', 'アニオン'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['590-55-6'],
#     '化学式': ['CH2NO5P2-'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ヘキサニトロジフェニルアミン',
#    'WikipediaID': 1353576,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Hexanitrodiphenylamine'],
#     '用途': ['魚雷用爆薬の成分'],
#     '種類': ['爆薬'],
#     '商標名': [],
#     '特性': ['黄色', '毒性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['131-73-7'],
#     '化学式': ['C12H5N7O12'],
#     '密度': ['1.58 g/cm3'],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '炭酸ベリリウム',
#    'WikipediaID': 1905810,
#    'Attributes': {'ふりがな': 'たんさんベリリウム',
#     '別称': ['beryllium carbonate'],
#     '用途': [],
#     '種類': ['炭酸塩'],
#     '商標名': [],
#     '特性': ['無色', '結晶'],
#     '原材料': ['二酸化炭素中', '水酸化ベリリウム', '水', '二酸化炭素'],
#     '製造方法': ['水酸化ベリリウムを水に懸濁させて二酸化炭素を通じながら、二酸化炭素中で濃縮すると四水和物の結晶が析出する。'],
#     '生成化合物': [],
#     'CAS番号': ['13106-47-3'],
#     '化学式': ['BeCO3'],
#     '密度': ['3'],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'トリメチルアルミニウム',
#    'WikipediaID': 1334290,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Trimethylaluminium', 'aluminium trimethyl'],
#     '用途': ['反応の触媒', 'オレフィン重合の助触媒', 'メチルアルミノキサン'],
#     '種類': ['有機アルミニウム化合物'],
#     '商標名': [],
#     '特性': ['無色', '液体'],
#     '原材料': ['助触媒', 'メチルアルミノキサン', '水', 'トリメチルアルミニウム'],
#     '製造方法': ['トリメチルアルミニウムを注意深く水と反応させて得られるメチルアルミノキサンは、オレフィン重合の助触媒として用いられる。'],
#     '生成化合物': [],
#     'CAS番号': ['75-24-1'],
#     '化学式': ['C6H18Al2'],
#     '密度': ['0.752 g/mL'],
#     '融点': ['15 °C'],
#     '沸点': ['125 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ソルビン酸ナトリウム',
#    'WikipediaID': 2902583,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Sodium sorbate', 'sodium (2E,4E)-hexa-2,4-dienoate'],
#     '用途': ['ソルビン酸溶液', '合同食品添加物専門会議', 'E201の食品添加物', '毒性の懸念', '食品衛生法', '防腐剤'],
#     '種類': [],
#     '商標名': [],
#     '特性': ['毒性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['7757-81-5'],
#     '化学式': ['C6H7NaO2'],
#     '密度': [],
#     '融点': [],
#     '沸点': ['233 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'バカンピシリン',
#    'WikipediaID': 259804,
#    'Attributes': {'ふりがな': [],
#     '別称': ['1-Ethoxycarbonyloxyethyl (2S,5R)-6-[[(2R)-2-amino-2-phenylacetyl]amino]-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylate',
#      'Bacampicillin'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['37661-08-8'],
#     '化学式': ['C21H27N3O7S'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'シンコニン',
#    'WikipediaID': 2812272,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Cinchonine'],
#     '用途': ['不斉合成', '有機化学'],
#     '種類': ['アルカロイド'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['118-10-5'],
#     '化学式': ['C19H22N2O'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'リン化ガリウム',
#    'WikipediaID': 3476127,
#    'Attributes': {'ふりがな': 'リンかガリウム',
#     '別称': ['GaP', 'gallanylidynephosphane', 'gallium phosphide'],
#     '用途': ['n型半導体', '光学材料', 'p型半導体のドーパント'],
#     '種類': ['リン化物'],
#     '商標名': [],
#     '特性': ['無臭', '不溶性', 'オレンジ色'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['12063-98-8'],
#     '化学式': ['GaP'],
#     '密度': ['4.138 g/cm3'],
#     '融点': ['1477 °C', '230 °F', '2691 °F', '1750 K'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ベンペリドール',
#    'WikipediaID': 3678817,
#    'Attributes': {'ふりがな': [],
#     '別称': ['1-{1-[4-(4-fluorophenyl)-4-oxobutyl]piperidin-4-yl}-1,3-dihydro-2H-benzimidazol-2-one',
#      'Benperidol'],
#     '用途': ['酢酸シプロテロン等の抗アンドロゲン薬の代替'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['983-42-6'],
#     '化学式': ['C22H24FN3O2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'Γ-ヒドロキシ酪酸',
#    'WikipediaID': 1059604,
#    'Attributes': {'ふりがな': 'ガンマヒドロキシらくさん',
#     '別称': ['4-Hydroxybutanoic acid'],
#     '用途': ['麻薬及び向精神薬取締法',
#      '麻薬指定',
#      '睡眠薬や脱法ドラッグ',
#      'ナルコレプシーの治療薬',
#      '製剤',
#      'アルコール依存症の治療薬'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['591-81-1'],
#     '化学式': ['C4H8O3'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'シクロヘキセン',
#    'WikipediaID': 527952,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Hexanaphthylene',
#      'Benzenetetrahydride',
#      '1,2,3,4-Tetrahydrobenzene',
#      'cyclohexene',
#      'Cyclohex-1-ene',
#      'Tetrahydrobenzene',
#      'UN 2256',
#      'Cyclohexene'],
#     '用途': ['溶媒',
#      '付臭剤',
#      '接着剤の溶剤',
#      '硫黄分',
#      '都市ガス',
#      '種々の薬品',
#      'シクロヘキセン誘導体',
#      '特有の悪臭'],
#     '種類': ['過酸化物'],
#     '商標名': [],
#     '特性': ['液体', '悪臭'],
#     '原材料': ['シクロヘキセン', 'ベンゼン', '水素化'],
#     '製造方法': ['シクロヘキセンはベンゼンの部分的な水素化によって得られる。'],
#     '生成化合物': [],
#     'CAS番号': ['110-83-8'],
#     '化学式': ['C6H10'],
#     '密度': ['0.8110 g/cm3'],
#     '融点': ['-154 °F',
#      '181 °F',
#      '10 °F',
#      '471.2 °F',
#      '-103.5 °C',
#      '356 K',
#      '170 K'],
#     '沸点': ['181 °F', '10 °F', '82.98 °C', '471.2 °F', '356 K'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ナブメトン',
#    'WikipediaID': 3608721,
#    'Attributes': {'ふりがな': [],
#     '別称': ['4-(6-methoxy-2-naphthyl)-2-butanone', 'Nabumetone'],
#     '用途': [],
#     '種類': ['官能基', 'ナフタレン'],
#     '商標名': [],
#     '特性': ['酸性', '活性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['42924-53-8'],
#     '化学式': ['C15H16O2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '1-プロパノール',
#    'WikipediaID': 373839,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Propan-1-ol',
#      'n-Propyl alcohol n-Propanol n-PrOH Ethylcarbinol 1-Hydroxypropane Propanol Propionic alcohol Propionyl alcohol Propionylol Propyl alcohol Propylic alcohol Propylol'],
#     '用途': [],
#     '種類': ['触媒'],
#     '商標名': [],
#     '特性': ['特異臭', '無色', '毒性', '液体'],
#     '原材料': ['プロパノール',
#      'ロジウム錯体等',
#      '全てエチレン',
#      '触媒',
#      'フーゼル油',
#      'プロピオンアルデヒド',
#      '水素化',
#      'ヒドロホルミル化'],
#     '製造方法': ['1-プロパノールはフーゼル油を蒸留することで得られていたが、現在はほぼ全てエチレンのヒドロホルミル化によって得られるプロピオンアルデヒドを、ロジウム錯体等の触媒によって水素化する方法で作られている（下記の反応）。'],
#     '生成化合物': [],
#     'CAS番号': ['71-23-8'],
#     '化学式': ['C3H8O'],
#     '密度': ['0.803 g/mL'],
#     '融点': ['147 K',
#      '-195 °F',
#      '206-208 °F',
#      '−126.5 ℃',
#      '-126 °C',
#      '370-371 K'],
#     '沸点': ['97.15 ℃', '206-208 °F', '370-371 K', '97-98 °C'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アラントイン酸',
#    'WikipediaID': 2979061,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Allantoic acid',
#      '2,2-Di[(aminocarbonyl)amino]acetic acid Diureidoacetate'],
#     '用途': [],
#     '種類': ['尿素', '有機化合物', '酸'],
#     '商標名': [],
#     '特性': ['結晶性'],
#     '原材料': ['加水分解', 'アラントイン'],
#     '製造方法': ['アラントインの加水分解によって得られる結晶性の酸である。'],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C4H8N4O4'],
#     '密度': ['1'],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': '3-ヘプタノール',
#    'WikipediaID': 2857693,
#    'Attributes': {'ふりがな': [],
#     '別称': ['3-heptanol', 'Heptan-3-ol'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['589-82-2'],
#     '化学式': ['C7H16O'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'エチレンジオキシメタンフェタミン',
#    'WikipediaID': 3018289,
#    'Attributes': {'ふりがな': [],
#     '別称': ['4-Ethylenedioxy-N-methylamphetamine',
#      'EDMA',
#      '1-(2,3-dihydro-1,4-benzodioxin-6-yl)-N-methylpropan-2-amine',
#      '3'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': ['可能性'],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C12H17NO2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'ペンタコサン',
#    'WikipediaID': 2218883,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Pentacosane'],
#     '用途': [],
#     '種類': ['炭化水素'],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['629-99-2'],
#     '化学式': ['C25H52'],
#     '密度': [],
#     '融点': ['53℃'],
#     '沸点': ['403.55℃'],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アミリン',
#    'WikipediaID': 2704171,
#    'Attributes': {'ふりがな': [],
#     '別称': ['α: (3β)-Urs-12-en-3-ol',
#      'β-Amirin',
#      'α-Amirin',
#      'Olean-12-en-3β-ol',
#      'α-Amyrine',
#      'Viminalol',
#      'Amyrin',
#      'β-Amyrine',
#      'β: β-Amyrenol',
#      '3β-Hydroxyolean-12-ene',
#      'β: (3β)-Olean-12-en-3-ol',
#      'α: α-Amyrenol',
#      'Urs-12-en-3β-ol'],
#     '用途': [],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': ['638-95-9', '559-70-6'],
#     '化学式': ['C30H50O'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'アダムス触媒',
#    'WikipediaID': 1483298,
#    'Attributes': {'ふりがな': 'アダムスしょくばい',
#     '別称': ["Adams' catalyst", 'Platinum(IV) oxide', '二酸化白金', '酸化白金'],
#     '用途': ['白金黒',
#      'ニルリン酸エステルの水素化分解',
#      '酸化物の状態',
#      '触媒',
#      '酸化反応',
#      '有機化学の分野',
#      '水素添加や水素化分解の触媒',
#      '水素化分解',
#      'パラジウム触媒'],
#     '種類': ['酸化物', '触媒', '水素'],
#     '商標名': [],
#     '特性': ['褐色', '粉末', '活性'],
#     '原材料': ['塩化白金酸アンモニウム((NH42PtCl6', 'アダムス触媒', '硝酸ナトリウム', '塩化白金酸H2PtCl6'],
#     '製造方法': ['アダムス触媒は塩化白金酸(H2PtCl6)または塩化白金酸アンモニウム((NH4)2PtCl6)を硝酸ナトリウムに溶融させて製造される。'],
#     '生成化合物': [],
#     'CAS番号': ['1314-15-4'],
#     '化学式': ['PtO2'],
#     '密度': ['10.2 g/cm³'],
#     '融点': ['450 °C', '842 °F', '723 K'],
#     '沸点': [],
#     '示性式': []}},
#   {'ENE': '化合物名',
#    'Name': 'オキサゾロン',
#    'WikipediaID': 3087706,
#    'Attributes': {'ふりがな': [],
#     '別称': ['Oxazolone'],
#     '用途': ['免疫学実験', 'オキサゾロン誘導体', '化学アレルゲン'],
#     '種類': [],
#     '商標名': [],
#     '特性': [],
#     '原材料': [],
#     '製造方法': [],
#     '生成化合物': [],
#     'CAS番号': [],
#     '化学式': ['C3H3NO2'],
#     '密度': [],
#     '融点': [],
#     '沸点': [],
#     '示性式': []}},
#   ...]}
