# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import json
import time
import pickle
import requests

# %%
class WikipediaAPIHandler(object):
    def __init__(self):
        self.base_query = "https://ja.wikipedia.org/w/api.php?action=query&format=json"
        
    def get_page_in_category(self, category):
        query = f"{self.base_query}&cmlimit=500&list=categorymembers&cmtitle=Category:{category}"
        resp_json = self._response(query)
        if resp_json is None:
            return None
        
        return {"article": self._get_member_article(resp_json), "subcategory": self._get_subcategory(resp_json)}
        
        
    def _response(self, query, error_wait=10, max_trial=10):
        i = 0
        while True:
            if i > max_trial:
                print("ERROR.")
                return None
            
            try:
                return requests.get(query).json()
            except requests.ConnectionError as e:
                print(e.args)
            except requests.HTTPError as e:
                print(e.args)
            except requests.Timeout as e:
                print(e.args)
            except requests.TooManyRedirects as e:
                print(e.args)
            except json.JSONDecodeError as e:
                print(e.args)
                return None
                
            time.sleep(error_wait)
            i += 1
            
    def _get_member_article(self, response):
        return [member['title'] for member in response['query']['categorymembers'] if member['ns'] is 0]
        
    def _get_subcategory(self, response):
        return [re.sub(r'^Category:', '', member['title']) for member in response['query']['categorymembers'] if member['ns'] is 14]

# %%
with open("../dump/noun_list.pickle", 'br') as f:
    noun_set = set(pickle.load(f))

# %%
wiki_handler = WikipediaAPIHandler()

# %%
category_list = pd.read_csv("../data/category_list.csv").category.tolist()
category_list = list(set(category_list) & noun_set)

i = 0
article_list = []
searched_category = []
while len(category_list) > 0:
    category = category_list.pop(0)
    
    if category in searched_category:
        continue
    else:
        searched_category.append(category)
    
    c_info = wiki_handler.get_page_in_category(category)
    time.sleep(1)
    
    if c_info is None:
        continue
    
    print(i, "\tcategory:", category)
    
    if len(c_info['article']) > 0:
        article_list.append(c_info['article'])
    if len(c_info['subcategory']) > 0:
        category_list += c_info['subcategory']
        category_list = list(set(category_list) & noun_set)
    
    i += 1
# Out:
# 0 	category: 着色料
# 1 	category: アンドロゲン
# 2 	category: バニロイド
# 3 	category: ウイスキー
# 4 	category: 通貨記号
# 5 	category: 塩化物
# 6 	category: 解毒剤
# 7 	category: 錯体化学
# 8 	category: アミノグリコシド系抗生物質
# 9 	category: 肥料
# 10 	category: タンパク質
# 11 	category: アゾ染料
# 12 	category: 酒
# 13 	category: 受容体
# 14 	category: 細胞接着分子
# 15 	category: インドールアルカロイド
# 16 	category: 薬理学
# 17 	category: 有毒ガス
# 18 	category: 光学材料
# 19 	category: ピレスロイド
# 20 	category: 高分子
# 21 	category: 栄養素
# 22 	category: シクリトール
# 23 	category: 漂白剤
# 24 	category: 非ステロイド性抗炎症薬
# 25 	category: 安息香酸エステル
# 26 	category: ワクチン
# 27 	category: アストラゼネカ
# 28 	category: 大腸菌
# 29 	category: ヘプトース
# 30 	category: マグネシウム
# 31 	category: リガンド
# 32 	category: スタチン
# 33 	category: 燃料
# 34 	category: エネルギー貯蔵
# 35 	category: カチオン
# 36 	category: 電池
# 37 	category: 超酸化物
# 38 	category: 気分安定薬
# 39 	category: 置換反応
# 40 	category: ウラン
# 41 	category: リチウム
# 42 	category: 防腐剤
# 43 	category: 免疫抑制剤
# 44 	category: アヌレン
# 45 	category: 向精神薬
# 46 	category: バイオディーゼル
# 47 	category: 鋼
# 48 	category: パーキンソン病
# 49 	category: シクロアルケン
# 50 	category: 化学
# 51 	category: 計算化学
# 52 	category: 高血圧治療薬
# 53 	category: インフルエンザ
# 54 	category: セルロース
# 55 	category: 麻薬向精神薬原料
# 56 	category: ポリエステル
# 57 	category: 医薬部外品
# 58 	category: リン酸エステル
# 59 	category: 性ホルモン
# 60 	category: 香水
# 61 	category: コミュニティ
# 62 	category: メタロセン
# 63 	category: 食品
# 64 	category: 食品産業
# 65 	category: ニトロフラン
# 66 	category: 抗原虫薬
# 67 	category: 抗不安薬
# 68 	category: レチノイド
# 69 	category: 嗅覚
# 70 	category: 筋弛緩剤
# 71 	category: イソシアニド
# 72 	category: エレベーター
# 73 	category: 化学反応
# 74 	category: 複素環式化合物
# 75 	category: オキサジン
# 76 	category: 材料
# 77 	category: エラストマー
# 78 	category: 衣料
# 79 	category: 繊維
# 80 	category: C型肝炎ウイルス
# 81 	category: テルル化物
# 82 	category: テルペノイド
# 83 	category: モノテルペン
# 84 	category: イリドイド
# 85 	category: チオエーテル
# 86 	category: グルコシノレート
# 87 	category: チアジン
# 88 	category: 抗がん剤
# 89 	category: アントラサイクリン
# 90 	category: ミトコンドリア
# 91 	category: 酸化物
# 92 	category: アミンオキシド
# 93 	category: 乳化剤
# 94 	category: ガラス
# 95 	category: 水和物
# 96 	category: 酸性雨
# 97 	category: 都市ガス
# 98 	category: 味の素
# 99 	category: 冷媒
# 100 	category: 内因性カンナビノイド
# 101 	category: 第一種特定化学物質
# 102 	category: 香
# 103 	category: オピオイド
# 104 	category: エルゴリン
# 105 	category: 鼻
# 106 	category: 二酸化ケイ素
# 107 	category: 半導体材料
# 108 	category: 日本酒
# 109 	category: 金属
# 110 	category: アミジン
# 111 	category: アルカン
# 112 	category: デンプン
# 113 	category: ポリエーテル
# 114 	category: リポタンパク質
# 115 	category: 飲料
# 116 	category: 非ベンゾジアゼピン系
# 117 	category: 銅
# 118 	category: 保護基
# 119 	category: エイコサノイド
# 120 	category: 田辺三菱製薬
# 121 	category: 熱力学
# 122 	category: エントロピー
# 123 	category: アルドヘキソース
# 124 	category: 電気化学
# 125 	category: リン化物
# 126 	category: 指示薬
# 127 	category: 有機リン化合物
# 128 	category: ホスホン酸
# 129 	category: トリカルボン酸
# 130 	category: 理論化学
# 131 	category: ジテルペン
# 132 	category: デプシペプチド
# 133 	category: 有機半導体
# 134 	category: 幻覚剤
# 135 	category: 藻類
# 136 	category: バナジウム
# 137 	category: 双性イオン
# 138 	category: フェライト
# 139 	category: 発癌性物質
# 140 	category: 石綿
# 141 	category: 糖タンパク質
# 142 	category: イミダゾピリミジン
# 143 	category: 宝石
# 144 	category: ヒドロキシ酸
# 145 	category: 地衣類
# 146 	category: 溶媒
# 147 	category: アミノ酸
# 148 	category: ペプチド
# 149 	category: 賦形剤
# 150 	category: 野菜
# 151 	category: ジュース
# 152 	category: 根菜
# 153 	category: 化学合成
# 154 	category: グラクソ・スミスクライン
# 155 	category: 糖類
# 156 	category: 二糖
# 157 	category: オリゴ糖
# 158 	category: 砂糖
# 159 	category: イミノ糖
# 160 	category: デオキシ糖
# 161 	category: アミノ糖
# 162 	category: 残留性有機汚染物質
# 163 	category: シアン酸塩
# 164 	category: リン脂質
# 165 	category: 酢酸エステル
# 166 	category: 精神刺激薬
# 167 	category: バルビツール酸系
# 168 	category: 獣医学
# 169 	category: ケタール
# 170 	category: 金属タンパク質
# 171 	category: ステロイドアルカロイド
# 172 	category: フラボノール
# 173 	category: ゴム
# 174 	category: タイヤ
# 175 	category: 醤油
# 176 	category: ベンゾジオキソール
# 177 	category: アルコール
# 178 	category: フラバノノール
# 179 	category: エノール
# 180 	category: 脂肪族アルコール
# 181 	category: グリコール
# 182 	category: フラバノール
# 183 	category: 有機化合物
# 184 	category: 補酵素
# 185 	category: 化学物質
# 186 	category: 元素
# 187 	category: スズ
# 188 	category: ハフニウム
# 189 	category: 塩素
# 190 	category: 亜鉛
# 191 	category: ネプツニウム
# 192 	category: 銀
# 193 	category: タングステン
# 194 	category: セレン
# 195 	category: アメリシウム
# 196 	category: イリジウム
# 197 	category: 薬
# 198 	category: カドミウム
# 199 	category: ベリリウム
# 200 	category: ルテニウム
# 201 	category: カリウム
# 202 	category: ニッケル
# 203 	category: ユウロピウム
# 204 	category: ラジウム
# 205 	category: チタン
# 206 	category: ロジウム
# 207 	category: 鎮痛剤
# 208 	category: 脂質
# 209 	category: ファイザー
# 210 	category: フッ素
# 211 	category: トリテルペン
# 212 	category: プロドラッグ
# 213 	category: 火薬
# 214 	category: キセノン
# 215 	category: アヤワスカ
# 216 	category: アクチニウム
# 217 	category: ポリオレフィン
# 218 	category: 甲虫
# 219 	category: ジルコニウム
# 220 	category: 止瀉薬
# 221 	category: 紫外線
# 222 	category: 無機化学
# 223 	category: 燃料電池
# 224 	category: フタル酸エステル
# 225 	category: 紅藻
# 226 	category: 環状ペプチド
# 227 	category: アンモニウム塩
# 228 	category: ケイ素
# 229 	category: ビスホスホネート
# 230 	category: 妊娠中絶
# 231 	category: 同位体
# 232 	category: 活性酸素
# 233 	category: 酢酸塩
# 234 	category: 酸化剤
# 235 	category: 過酸化物
# 236 	category: 硝酸塩
# 237 	category: アスコルビン酸
# 238 	category: 鉱物
# 239 	category: エポキシド
# 240 	category: ヘムタンパク質
# 241 	category: 分析化学
# 242 	category: 化学工業
# 243 	category: 脂質異常症
# 244 	category: パラジウム
# 245 	category: グリコサミノグリカン
# 246 	category: ネコ
# 247 	category: マイコトキシン
# 248 	category: 化学発光
# 249 	category: 鉄
# 250 	category: カルボン酸エステル
# 251 	category: 酸素
# 252 	category: 骨
# 253 	category: 酸
# 254 	category: 臭素
# 255 	category: 香料
# 256 	category: クリプトン
# 257 	category: 酸塩基指示薬
# 258 	category: 有機酸
# 259 	category: カルボン酸
# 260 	category: カルボン酸塩化物
# 261 	category: 過塩素酸塩
# 262 	category: ホルモン
# 263 	category: ルビジウム
# 264 	category: 医療
# 265 	category: 代替医療
# 266 	category: 診療科
# 267 	category: ダイヤモンド
# 268 	category: 生合成
# 269 	category: 有機塩素化合物
# 270 	category: ラクタム
# 271 	category: 麻酔薬
# 272 	category: 配糖体
# 273 	category: 物質
# 274 	category: 原子
# 275 	category: 電子
# 276 	category: 半導体
# 277 	category: 気体
# 278 	category: 穀物
# 279 	category: 薬品
# 280 	category: 酵素阻害剤
# 281 	category: 水酸化物
# 282 	category: ジエン
# 283 	category: 放射線療法
# 284 	category: アセトアミド
# 285 	category: アセトアニリド
# 286 	category: 大気
# 287 	category: 空
# 288 	category: 霧
# 289 	category: ラクトール
# 290 	category: イットリウム
# 291 	category: バリウム
# 292 	category: フェニルプロパノイド
# 293 	category: リグナン
# 294 	category: 光化学
# 295 	category: 血液
# 296 	category: シアノトキシン
# 297 	category: シクロペンタジエニル錯体
# 298 	category: 磁性体
# 299 	category: タンニン
# 300 	category: 重合禁止剤
# 301 	category: ビール
# 302 	category: 糖尿病
# 303 	category: 化合物
# 304 	category: 希ガス化合物
# 305 	category: コーヒー
# 306 	category: 自閉症
# 307 	category: 血液検査
# 308 	category: ジオキソラン
# 309 	category: 化学兵器
# 310 	category: ガスマスク
# 311 	category: マレイミド
# 312 	category: フェニルプロペン
# 313 	category: 硫酸塩鉱物
# 314 	category: ダイヤモンド類似石
# 315 	category: マクロライド系抗生物質
# 316 	category: ホウ素
# 317 	category: サポニン
# 318 	category: 抗てんかん薬
# 319 	category: 緩衝剤
# 320 	category: 薬局
# 321 	category: 金属元素
# 322 	category: 甘味料
# 323 	category: 豆類
# 324 	category: 食品添加物
# 325 	category: トマト
# 326 	category: サマリウム
# 327 	category: 白金
# 328 	category: オスミウム
# 329 	category: テトラヒドロイソキノリン
# 330 	category: 内分泌攪乱物質
# 331 	category: 抗うつ薬
# 332 	category: 四環系抗うつ薬
# 333 	category: ショウガ
# 334 	category: アンチモン
# 335 	category: 有機硫黄化合物
# 336 	category: イソチオシアネート
# 337 	category: チオ尿素
# 338 	category: スルホキシド
# 339 	category: チオカルバマート
# 340 	category: スルホンアミド
# 341 	category: 超伝導
# 342 	category: 免疫学
# 343 	category: ピラゾロピリミジン
# 344 	category: 毒
# 345 	category: アナボリックステロイド
# 346 	category: ステロイド
# 347 	category: ビスマス
# 348 	category: 加工食品
# 349 	category: 菓子
# 350 	category: 転写因子
# 351 	category: ラクトン
# 352 	category: セスキテルペンラクトン
# 353 	category: クメスタン
# 354 	category: プロスタグランジン
# 355 	category: サイトカイニン
# 356 	category: 一般用医薬品
# 357 	category: 非線形光学材料
# 358 	category: 潤滑剤
# 359 	category: 利尿薬
# 360 	category: ニオブ
# 361 	category: ヌクレオシド
# 362 	category: 分光学
# 363 	category: エステル
# 364 	category: 染料
# 365 	category: 蛍光色素
# 366 	category: スカンジウム
# 367 	category: タリウム
# 368 	category: シロップ
# 369 	category: エーテル
# 370 	category: スルホン
# 371 	category: リキュール
# 372 	category: RNAウイルス
# 373 	category: メチルエステル
# 374 	category: 化学式
# 375 	category: 飼料
# 376 	category: モリブデン
# 377 	category: 除草剤
# 378 	category: 微生物学
# 379 	category: イッテルビウム
# 380 	category: 核磁気共鳴
# 381 	category: 催涙剤
# 382 	category: 毒物
# 383 	category: C型肝炎
# 384 	category: アントシアニジン
# 385 	category: 油脂
# 386 	category: 糖酸
# 387 	category: ケイ酸塩鉱物
# 388 	category: クラウンエーテル
# 389 	category: プリン
# 390 	category: クェルセチン配糖体
# 391 	category: 昆虫
# 392 	category: スルホン酸
# 393 	category: 配位子
# 394 	category: ポルフィリン
# 395 	category: 毒素
# 396 	category: 血管拡張薬
# 397 	category: アゾ化合物
# 398 	category: シロアリ
# 399 	category: 駆虫薬
# 400 	category: 糖アルコール
# 401 	category: 還元剤
# 402 	category: 古細菌
# 403 	category: 大豆
# 404 	category: 炭化水素
# 405 	category: 有機臭素化合物
# 406 	category: 金属アミド
# 407 	category: 造影剤
# 408 	category: 必須アミノ酸
# 409 	category: 茶
# 410 	category: ペルオキシド
# 411 	category: ゲルマニウム
# 412 	category: 光合成色素
# 413 	category: ケンペロール配糖体
# 414 	category: 雲
# 415 	category: レニウム
# 416 	category: 抗真菌薬
# 417 	category: 殺鼠剤
# 418 	category: ウイルス
# 419 	category: 水素
# 420 	category: 臭化物
# 421 	category: 抗ヒスタミン薬
# 422 	category: アセタール
# 423 	category: ヨウ素
# 424 	category: 芳香族化合物
# 425 	category: ビフェニル
# 426 	category: ベンゾトリアゾール
# 427 	category: インダゾール
# 428 	category: チオフェン
# 429 	category: キサンテン
# 430 	category: イソオキサゾール
# 431 	category: キノリン
# 432 	category: ベンゾモルファン
# 433 	category: ピリダジン
# 434 	category: ピロール
# 435 	category: ベンゾイミダゾール
# 436 	category: モルフィナン
# 437 	category: フィトケミカル
# 438 	category: 多孔質
# 439 	category: 植物
# 440 	category: 硫黄
# 441 	category: 食用植物
# 442 	category: 食虫植物
# 443 	category: 生命の起源
# 444 	category: ボラン
# 445 	category: グアニジン
# 446 	category: クロム
# 447 	category: トウモロコシ
# 448 	category: 有機リン系殺虫剤
# 449 	category: チオリン酸エステル
# 450 	category: オキソ酸
# 451 	category: 植物成長調整剤
# 452 	category: オキサゾール
# 453 	category: レーザー
# 454 	category: チョコレート
# 455 	category: 接着剤
# 456 	category: 木
# 457 	category: 電子顕微鏡
# 458 	category: コバルト
# 459 	category: 髪
# 460 	category: 環境問題
# 461 	category: 血液学
# 462 	category: 草
# 463 	category: 花火
# 464 	category: ハンセン病
# 465 	category: ドーピング
# 466 	category: ポリフェノール
# 467 	category: アルミニウム
# 468 	category: アミド
# 469 	category: カルバミン酸
# 470 	category: 尿素
# 471 	category: 天然染料
# 472 	category: リン
# 473 	category: 酸化還元指示薬
# 474 	category: 硝酸エステル
# 475 	category: 超分子
# 476 	category: 翻訳後修飾
# 477 	category: 環式化合物
# 478 	category: トリウム
# 479 	category: 脂肪酸
# 480 	category: 土壌
# 481 	category: 有機化学
# 482 	category: チオエステル
# 483 	category: 脳
# 484 	category: 乳
# 485 	category: 牛乳
# 486 	category: 光合成
# 487 	category: 建築材料
# 488 	category: 睡眠薬
# 489 	category: 必須栄養素
# 490 	category: 可塑剤
# 491 	category: コンクリート
# 492 	category: フラーレン
# 493 	category: テクトケイ酸塩鉱物
# 494 	category: 紅茶
# 495 	category: 界面活性剤
# 496 	category: フェロモン
# 497 	category: オルトエステル
# 498 	category: ヨウ化物
# 499 	category: インペリアル・ケミカル・インダストリーズ
# 500 	category: 分子生物学
# 501 	category: 電気泳動
# 502 	category: ニトロベンゼン
# 503 	category: 液晶
# 504 	category: 合金
# 505 	category: プリンター
# 506 	category: 物理化学
# 507 	category: 蛍光
# 508 	category: 琥珀
# 509 	category: チューインガム
# 510 	category: 危険物
# 511 	category: 糸
# 512 	category: 鉱石
# 513 	category: ガス燃料
# 514 	category: 抗酸化物質
# 515 	category: 植物エストロゲン
# 516 	category: 天然樹脂
# 517 	category: 金
# 518 	category: マンガン
# 519 	category: 神経毒
# 520 	category: 窒素
# 521 	category: 官能基
# 522 	category: 染色体
# 523 	category: ハロメタン
# 524 	category: ナス科
# 525 	category: 酸無水物
# 526 	category: ノバルティス
# 527 	category: 表面処理
# 528 	category: アミン
# 529 	category: オキソアニオン
# 530 	category: 塩素酸塩
# 531 	category: リン酸塩
# 532 	category: イソキノリン
# 533 	category: 生薬
# 534 	category: 亜硝酸塩
# 535 	category: トリプタミン
# 536 	category: 医薬品
# 537 	category: 剤形
# 538 	category: 漢方薬
# 539 	category: 抗体
# 540 	category: バナジン酸塩
# 541 	category: マンガン酸塩
# 542 	category: ヒダントイン
# 543 	category: 画像診断
# 544 	category: 無機顔料
# 545 	category: アルカロイド
# 546 	category: 合成樹脂
# 547 	category: 神経学
# 548 	category: タンタル
# 549 	category: 砂
# 550 	category: フラバノン
# 551 	category: ピペリジン
# 552 	category: 有機ハロゲン化合物
# 553 	category: クマリン
# 554 	category: ホウ化物
# 555 	category: 芳香族アミン
# 556 	category: アニオン
# 557 	category: 民間療法
# 558 	category: 鉛
# 559 	category: 味覚
# 560 	category: セラミック材料
# 561 	category: 単糖
# 562 	category: ヘキソース
# 563 	category: 同素体
# 564 	category: カルシウム
# 565 	category: ホルムアミド
# 566 	category: シクロアルカン
# 567 	category: シクロプロパン
# 568 	category: シクロヘキサン
# 569 	category: 核磁気共鳴画像法
# 570 	category: 核酸
# 571 	category: 酢酸
# 572 	category: トリアシルグリセロール
# 573 	category: 栄養補助食品
# 574 	category: 大気汚染
# 575 	category: 石油備蓄
# 576 	category: 真正細菌
# 577 	category: 大員環化合物
# 578 	category: 炭酸塩
# 579 	category: 炭酸カルシウム
# 580 	category: 無機化合物
# 581 	category: 生体物質
# 582 	category: ベンゾニトリル
# 583 	category: チオール
# 584 	category: 過テクネチウム酸塩
# 585 	category: アゾール
# 586 	category: 胆汁酸
# 587 	category: 有機反応
# 588 	category: イオノフォア
# 589 	category: 付加反応
# 590 	category: ピラゾール
# 591 	category: 特定毒物
# 592 	category: 環化付加反応
# 593 	category: モノマー
# 594 	category: アズキ
# 595 	category: 色素
# 596 	category: 水銀
# 597 	category: 固体物理学
# 598 	category: 地球化学
# 599 	category: 熱伝導
# 600 	category: 珪藻
# 601 	category: 化粧品
# 602 	category: マクロライド
# 603 	category: 公衆衛生
# 604 	category: 疫学
# 605 	category: ベンゾチアゾール
# 606 	category: 有機金属化学
# 607 	category: アルケン
# 608 	category: ナトリウム
# 609 	category: 蜂蜜
# 610 	category: カロテノイド
# 611 	category: 亜硝酸エステル
# 612 	category: 光触媒
# 613 	category: 合成ムスク
# 614 	category: アダマンタン
# 615 	category: ファイトアレキシン
# 616 	category: 過マンガン酸塩
# 617 	category: 炭素
# 618 	category: 炭
# 619 	category: 塩
# 620 	category: シアン化物
# 621 	category: 周期表
# 622 	category: チオシアン酸塩
# 623 	category: 複塩
# 624 	category: 神経伝達物質
# 625 	category: 水
# 626 	category: テトラピロール
# 627 	category: 湿度
# 628 	category: 顕微鏡
# 629 	category: 硫酸塩
# 630 	category: ヨウ素酸塩
# 631 	category: 殺虫剤
# 632 	category: ネオニコチノイド
# 633 	category: 病原体
# 634 	category: 葉酸
# 635 	category: 調味料
# 636 	category: ジカルボン酸
# 637 	category: ソース
# 638 	category: 製菓
# 639 	category: 依存症
# 640 	category: トリアジン
# 641 	category: イミド
# 642 	category: 塗料
# 643 	category: 農薬
# 644 	category: ワイン
# 645 	category: 煙
# 646 	category: 土壌汚染
# 647 	category: 果実酒
# 648 	category: ケトテトロース
# 649 	category: ピラゾロン
# 650 	category: 顔料
# 651 	category: トロパン
# 652 	category: ポロニウム
# 653 	category: キヌクリジン
# 654 	category: 生化学
# 655 	category: 細胞外マトリックス
# 656 	category: 重合反応
# 657 	category: インドール
# 658 	category: ハスバナン
# 659 	category: ポリアミン
# 660 	category: 相転移
# 661 	category: ジスルフィド
# 662 	category: 氷
# 663 	category: イノシトール
# 664 	category: 配位高分子
# 665 	category: 有機ケイ素化合物
# 666 	category: 唐辛子
# 667 	category: 転位反応
# 668 	category: 褐藻
# 669 	category: ベンズアルデヒド
# 670 	category: ヒドロキシベンズアルデヒド
# 671 	category: イミダゾール
# 672 	category: テルル
# 673 	category: テクネチウム
# 674 	category: チオ硫酸塩
# 675 	category: ケトペントース
# 676 	category: 木材
# 677 	category: 蛍光体
# 678 	category: 太陽電池
# 679 	category: インジウム
# 680 	category: 抗寄生虫薬
# 681 	category: ソフトドリンク
# 682 	category: 炭酸飲料
# 683 	category: 亜硫酸塩
# 684 	category: 培地
# 685 	category: トリアゾール
# 686 	category: エボラ出血熱
# 687 	category: カルバゾール
# 688 	category: イオン
# 689 	category: プラズマ
# 690 	category: シクロプロペン
# 691 	category: ナフチリジン
# 692 	category: カルコン
# 693 	category: カンナビノイド
# 694 	category: ケイ酸塩
# 695 	category: クロロベンゼン
# 696 	category: チアゾール
# 697 	category: ヌクレオチド
# 698 	category: 絶滅危惧種
# 699 	category: ポリケチド
# 700 	category: 獣医師
# 701 	category: 大麻
# 702 	category: 炭酸エステル
# 703 	category: 石鹸
# 704 	category: フラボノイド
# 705 	category: オーロン
# 706 	category: 塩化ナトリウム
# 707 	category: 酢
# 708 	category: 皮膚
# 709 	category: 乳腺
# 710 	category: 硫酸エステル
# 711 	category: 誘電体
# 712 	category: アジリジン
# 713 	category: フェネチルアミン
# 714 	category: カテコールアミン
# 715 	category: 石油製品
# 716 	category: 石油精製
# 717 	category: プルトニウム
# 718 	category: 天然ガス
# 719 	category: ケトン
# 720 	category: ジケトン
# 721 	category: アルツハイマー病
# 722 	category: コンブ
# 723 	category: イネ
# 724 	category: 異性体
# 725 	category: 必須脂肪酸
# 726 	category: 環状エーテル
# 727 	category: ピラン
# 728 	category: テトラヒドロフラン
# 729 	category: 細胞生物学
# 730 	category: モリブデン酸塩
# 731 	category: 細胞周期
# 732 	category: 柔軟剤
# 733 	category: テトラフルオロホウ酸塩
# 734 	category: 反応中間体
# 735 	category: 脊椎
# 736 	category: 植物ホルモン
# 737 	category: ケトース
# 738 	category: セラミックス
# 739 	category: 化石燃料
# 740 	category: 石炭
# 741 	category: フラボン
# 742 	category: 石油
# 743 	category: 乳製品
# 744 	category: チーズ
# 745 	category: ピリミジン
# 746 	category: 花
# 747 	category: 神経変性疾患
# 748 	category: テトラゾール
# 749 	category: ピラジン
# 750 	category: フェナジン
# 751 	category: アレルギー疾患
# 752 	category: 花粉症
# 753 	category: 二酸化炭素
# 754 	category: 抗生物質
# 755 	category: 水道
# 756 	category: クロム酸塩
# 757 	category: 麦角アルカロイド
# 758 	category: 爆薬
# 759 	category: ペントース
# 760 	category: 芳香族炭化水素
# 761 	category: インダン
# 762 	category: ジアゾアミノ化合物
# 763 	category: ジヒドロピリジン
# 764 	category: 卵
# 765 	category: アジ化物
# 766 	category: ゴキブリ
# 767 	category: フタルイミド
# 768 	category: 全合成
# 769 	category: 鉄硫黄タンパク質
# 770 	category: 塩基
# 771 	category: 有糸分裂
# 772 	category: 細胞シグナリング
# 773 	category: Gタンパク質
# 774 	category: エンジイン
# 775 	category: 美容
# 776 	category: 抗炎症薬
# 777 	category: 雷酸塩
# 778 	category: オゾン層破壊
# 779 	category: スクシンイミド
# 780 	category: 細胞
# 781 	category: 温室効果ガス
# 782 	category: 燃料電池車
# 783 	category: チアゾリジン
# 784 	category: 花粉
# 785 	category: 炭化物
# 786 	category: 解糖系
# 787 	category: キサンチン
# 788 	category: ポロニウム化物
# 789 	category: アルキン
# 790 	category: 次亜塩素酸塩
# 791 	category: ピロリジン
# 792 	category: ピロリジジン
# 793 	category: ハーブ
# 794 	category: ナフタレン
# 795 	category: 果物
# 796 	category: ブドウ
# 797 	category: ブランデー
# 798 	category: リンゴ
# 799 	category: ベリー
# 800 	category: イチゴ
# 801 	category: バナナ
# 802 	category: 多環芳香族炭化水素
# 803 	category: アントラセン
# 804 	category: 抗凝固薬
# 805 	category: 抗痛風薬
# 806 	category: 抗ウイルス薬
# 807 	category: 触媒
# 808 	category: 酪酸エステル
# 809 	category: 麻薬
# 810 	category: 細胞骨格
# 811 	category: 圧力
# 812 	category: バター
# 813 	category: 劇物
# 814 	category: ピロリドン
# 815 	category: モノリグノール
# 816 	category: 神経
# 817 	category: アルミノケイ酸塩
# 818 	category: テトラヒドロピラン
# 819 	category: ポリオール
# 820 	category: 糖脂質
# 821 	category: サイトカイン
# 822 	category: ピペラジン
# 823 	category: アルドース
# 824 	category: 洗剤
# 825 	category: 選択的セロトニン再取り込み阻害薬
# 826 	category: 皮膚科学
# 827 	category: 外傷
# 828 	category: 石油産業
# 829 	category: 油田
# 830 	category: エストロゲン
# 831 	category: 医学
# 832 	category: 磁石
# 833 	category: セスキテルペン
# 834 	category: バイオマーカー
# 835 	category: 核燃料
# 836 	category: 固体
# 837 	category: 木工
# 838 	category: 分子
# 839 	category: ガリウム
# 840 	category: 医師
# 841 	category: ピリジン
# 842 	category: アクリジン
# 843 	category: アニリン
# 844 	category: フェノール
# 845 	category: サリチル酸
# 846 	category: テトラヒドロキノリン
# 847 	category: 核燃料再処理工場
# 848 	category: 脱離反応
# 849 	category: 抗コリン薬
# 850 	category: フェノチアジン
# 851 	category: ニトリル
# 852 	category: トポイソメラーゼ阻害剤
# 853 	category: 有機フッ素化合物
# 854 	category: 生理学
# 855 	category: フレーバー
# 856 	category: 抗不整脈薬
# 857 	category: アントラキノン
# 858 	category: ラセタム
# 859 	category: ベンズアミド
# 860 	category: 感染症
# 861 	category: ベンゼン誘導体
# 862 	category: 安息香酸
# 863 	category: 酵素
# 864 	category: プロテインキナーゼ
# 865 	category: セルピン
# 866 	category: ジヒドロキシ安息香酸
# 867 	category: ベンゾフェノン
# 868 	category: リアーゼ
# 869 	category: ヒドラゾン
# 870 	category: 非定型抗精神病薬
# 871 	category: ビタミン
# 872 	category: ヒ素
# 873 	category: エノン
# 874 	category: トロポン
# 875 	category: 銅合金
# 876 	category: アヘン
# 877 	category: アルデヒド
# 878 	category: セリウム
# 879 	category: 皮膚疾患
# 880 	category: 投与経路
# 881 	category: 抗精神病薬
# 882 	category: 末梢神経系
# 883 	category: 労働災害
# 884 	category: 真空
# 885 	category: 淡水
# 886 	category: アリ
# 887 	category: チタン酸塩
# 888 	category: 薄膜
# 889 	category: 食材
# 890 	category: 脳神経

# %%
compound_set = set(pd.read_csv("../data/compound_list.csv")['compound'].tolist())

# %%
noun_in_category_and_title = list((set(flatten(article_list) + searched_category) & noun_set) - compound_set)

# %%
pd.DataFrame(
    {"noun": noun_in_category_and_title}
).to_csv("../data/noun_list_in_category_and_title.csv", index=False)

# %%
len(noun_in_category_and_title)
# Out:
# 2109
